# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass;

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data: pd.DataFrame) -> tuple:
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x: pd.DataFrame) -> pd.DataFrame:
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true: np.ndarray, y_pred: np.ndarray, title: str='') -> None:
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name: str, title: str, ylim: int=5) -> None:
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(
        history.history[f'val_{metric_name}'],
        color='green',
        label=f'val_{metric_name}'
    )
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI: str = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df: pd.DataFrame = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train: pd.DataFrame
test: pd.DataFrame
train, test = train_test_split(df, test_size=0.2)
train_stats: pd.DataFrame = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y: tuple = format_output(train)
test_Y: tuple = format_output(test)

# Normalize the training and test data
norm_train_X: pd.DataFrame = norm(train)
norm_test_X: pd.DataFrame = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer: tf.keras.layers.Layer = Input(shape=(len(train.columns),))
first_dense: tf.keras.layers.Layer = Dense(
    units='128', activation='relu'
)(input_layer)
second_dense: tf.keras.layers.Layer = Dense(
    units='128', activation='relu'
)(first_dense)

# Y1 output will be fed directly from the second dense
y1_output: tf.keras.layers.Layer = Dense(
    units='1', name='y1_output'
)(second_dense)
third_dense: tf.keras.layers.Layer = Dense(
    units='64', activation='relu'
)(second_dense);

# Y2 output will come via the third dense
y2_output: tf.keras.layers.Layer = Dense(
    units='1', name='y2_output'
)(third_dense);

# Define the model with the input layer and a list of output layers
model: tf.keras.Model = Model(
    inputs=input_layer, outputs=[y1_output, y2_output]
);

print(model.summary());
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both 
# outputs
optimizer: tf.keras.optimizers.Optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(
    optimizer=optimizer,
    loss={'y1_output': 'mse', 'y2_output': 'mse'},
    metrics={
        'y1_output': tf.keras.metrics.RootMeanSquaredError(),
        'y2_output': tf.keras.metrics.RootMeanSquaredError()
    }
);

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history: tf.keras.callbacks.History = model.fit(
    norm_train_X,
    train_Y,
    epochs=500,
    batch_size=10,
    validation_data=(norm_test_X, test_Y)
);
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 248.3374 - y1_output_loss: 115.5784 - y2_output_loss: 130.6033 - y1_output_root_mean_squared_error: 10.8002 - y2_output_root_mean_squared_error: 11.4757 - val_loss: 73.9895 - val_y1_output_loss: 18.1895 - val_y2_output_loss: 53.9622 - val_y1_output_root_mean_squared_error: 4.3064 - val_y2_output_root_mean_squared_error: 7.4461
# Epoch 2/500
# 614/614 [==============================] - 0s 164us/sample - loss: 31.7033 - y1_output_loss: 12.4555 - y2_output_loss: 18.9682 - y1_output_root_mean_squared_error: 3.5452 - y2_output_root_mean_squared_error: 4.3744 - val_loss: 28.4821 - val_y1_output_loss: 10.5333 - val_y2_output_loss: 17.0591 - val_y1_output_root_mean_squared_error: 3.3008 - val_y2_output_root_mean_squared_error: 4.1936
# Epoch 3/500
# 614/614 [==============================] - 0s 145us/sample - loss: 27.6682 - y1_output_loss: 10.6651 - y2_output_loss: 16.9364 - y1_output_root_mean_squared_error: 3.2569 - y2_output_root_mean_squared_error: 4.1305 - val_loss: 22.2222 - val_y1_output_loss: 8.2825 - val_y2_output_loss: 13.5037 - val_y1_output_root_mean_squared_error: 2.9220 - val_y2_output_root_mean_squared_error: 3.6992
# Epoch 4/500
# 614/614 [==============================] - 0s 141us/sample - loss: 22.0463 - y1_output_loss: 9.1020 - y2_output_loss: 12.7578 - y1_output_root_mean_squared_error: 3.0301 - y2_output_root_mean_squared_error: 3.5868 - val_loss: 21.4664 - val_y1_output_loss: 7.8565 - val_y2_output_loss: 12.9805 - val_y1_output_root_mean_squared_error: 2.8499 - val_y2_output_root_mean_squared_error: 3.6530
# Epoch 5/500
# 614/614 [==============================] - 0s 134us/sample - loss: 23.6081 - y1_output_loss: 9.5809 - y2_output_loss: 14.0518 - y1_output_root_mean_squared_error: 3.0939 - y2_output_root_mean_squared_error: 3.7464 - val_loss: 22.0434 - val_y1_output_loss: 8.1395 - val_y2_output_loss: 13.8794 - val_y1_output_root_mean_squared_error: 2.8943 - val_y2_output_root_mean_squared_error: 3.6968
# Epoch 6/500
# 614/614 [==============================] - 0s 151us/sample - loss: 20.4777 - y1_output_loss: 8.4052 - y2_output_loss: 12.1313 - y1_output_root_mean_squared_error: 2.8846 - y2_output_root_mean_squared_error: 3.4867 - val_loss: 23.3379 - val_y1_output_loss: 7.3363 - val_y2_output_loss: 15.1767 - val_y1_output_root_mean_squared_error: 2.7548 - val_y2_output_root_mean_squared_error: 3.9685
# Epoch 7/500
# 614/614 [==============================] - 0s 137us/sample - loss: 25.1577 - y1_output_loss: 9.5763 - y2_output_loss: 15.5882 - y1_output_root_mean_squared_error: 3.0866 - y2_output_root_mean_squared_error: 3.9536 - val_loss: 21.4689 - val_y1_output_loss: 9.7122 - val_y2_output_loss: 11.7883 - val_y1_output_root_mean_squared_error: 3.1149 - val_y2_output_root_mean_squared_error: 3.4302
# Epoch 8/500
# 614/614 [==============================] - 0s 139us/sample - loss: 23.1908 - y1_output_loss: 8.8709 - y2_output_loss: 14.1885 - y1_output_root_mean_squared_error: 2.9885 - y2_output_root_mean_squared_error: 3.7762 - val_loss: 23.0751 - val_y1_output_loss: 6.9818 - val_y2_output_loss: 16.2103 - val_y1_output_root_mean_squared_error: 2.6859 - val_y2_output_root_mean_squared_error: 3.9826
# Epoch 9/500
# 614/614 [==============================] - 0s 138us/sample - loss: 20.7653 - y1_output_loss: 8.1958 - y2_output_loss: 12.7592 - y1_output_root_mean_squared_error: 2.8645 - y2_output_root_mean_squared_error: 3.5440 - val_loss: 35.9676 - val_y1_output_loss: 9.3678 - val_y2_output_loss: 27.5285 - val_y1_output_root_mean_squared_error: 3.0807 - val_y2_output_root_mean_squared_error: 5.1456
# Epoch 10/500
# 614/614 [==============================] - 0s 139us/sample - loss: 17.8385 - y1_output_loss: 7.4558 - y2_output_loss: 10.3116 - y1_output_root_mean_squared_error: 2.7383 - y2_output_root_mean_squared_error: 3.2156 - val_loss: 23.3069 - val_y1_output_loss: 6.8729 - val_y2_output_loss: 16.7002 - val_y1_output_root_mean_squared_error: 2.6597 - val_y2_output_root_mean_squared_error: 4.0290
# Epoch 11/500
# 614/614 [==============================] - 0s 140us/sample - loss: 18.5617 - y1_output_loss: 7.5186 - y2_output_loss: 10.8768 - y1_output_root_mean_squared_error: 2.7551 - y2_output_root_mean_squared_error: 3.3123 - val_loss: 20.0262 - val_y1_output_loss: 6.7940 - val_y2_output_loss: 12.5713 - val_y1_output_root_mean_squared_error: 2.6518 - val_y2_output_root_mean_squared_error: 3.6047
# Epoch 12/500
# 614/614 [==============================] - 0s 153us/sample - loss: 17.8837 - y1_output_loss: 7.1238 - y2_output_loss: 10.6394 - y1_output_root_mean_squared_error: 2.6754 - y2_output_root_mean_squared_error: 3.2751 - val_loss: 17.5917 - val_y1_output_loss: 6.1838 - val_y2_output_loss: 10.8366 - val_y1_output_root_mean_squared_error: 2.5268 - val_y2_output_root_mean_squared_error: 3.3477
# Epoch 13/500
# 614/614 [==============================] - 0s 133us/sample - loss: 17.1264 - y1_output_loss: 7.0848 - y2_output_loss: 10.2303 - y1_output_root_mean_squared_error: 2.6471 - y2_output_root_mean_squared_error: 3.1811 - val_loss: 17.5279 - val_y1_output_loss: 6.0984 - val_y2_output_loss: 11.5407 - val_y1_output_root_mean_squared_error: 2.5050 - val_y2_output_root_mean_squared_error: 3.3546
# Epoch 14/500
# 614/614 [==============================] - 0s 135us/sample - loss: 17.7527 - y1_output_loss: 6.5777 - y2_output_loss: 11.1043 - y1_output_root_mean_squared_error: 2.5671 - y2_output_root_mean_squared_error: 3.3411 - val_loss: 35.2149 - val_y1_output_loss: 10.9842 - val_y2_output_loss: 23.1360 - val_y1_output_root_mean_squared_error: 3.3627 - val_y2_output_root_mean_squared_error: 4.8895
# Epoch 15/500
# 614/614 [==============================] - 0s 141us/sample - loss: 17.8543 - y1_output_loss: 6.8147 - y2_output_loss: 10.8805 - y1_output_root_mean_squared_error: 2.6206 - y2_output_root_mean_squared_error: 3.3146 - val_loss: 18.1869 - val_y1_output_loss: 5.9665 - val_y2_output_loss: 11.5931 - val_y1_output_root_mean_squared_error: 2.4823 - val_y2_output_root_mean_squared_error: 3.4677
# Epoch 16/500
# 614/614 [==============================] - 0s 140us/sample - loss: 16.4929 - y1_output_loss: 6.4901 - y2_output_loss: 9.9941 - y1_output_root_mean_squared_error: 2.5502 - y2_output_root_mean_squared_error: 3.1606 - val_loss: 14.9483 - val_y1_output_loss: 5.4684 - val_y2_output_loss: 9.0353 - val_y1_output_root_mean_squared_error: 2.3735 - val_y2_output_root_mean_squared_error: 3.0520
# Epoch 17/500
# 614/614 [==============================] - 0s 133us/sample - loss: 16.9974 - y1_output_loss: 6.5583 - y2_output_loss: 10.4600 - y1_output_root_mean_squared_error: 2.5496 - y2_output_root_mean_squared_error: 3.2399 - val_loss: 24.1202 - val_y1_output_loss: 9.5346 - val_y2_output_loss: 14.1459 - val_y1_output_root_mean_squared_error: 3.1015 - val_y2_output_root_mean_squared_error: 3.8080
# Epoch 18/500
# 614/614 [==============================] - 0s 134us/sample - loss: 14.0788 - y1_output_loss: 5.7051 - y2_output_loss: 8.4320 - y1_output_root_mean_squared_error: 2.3916 - y2_output_root_mean_squared_error: 2.8912 - val_loss: 20.6764 - val_y1_output_loss: 5.5562 - val_y2_output_loss: 14.5763 - val_y1_output_root_mean_squared_error: 2.3901 - val_y2_output_root_mean_squared_error: 3.8683
# Epoch 19/500
# 614/614 [==============================] - 0s 140us/sample - loss: 16.8479 - y1_output_loss: 6.4782 - y2_output_loss: 10.5741 - y1_output_root_mean_squared_error: 2.5246 - y2_output_root_mean_squared_error: 3.2364 - val_loss: 12.5098 - val_y1_output_loss: 4.7842 - val_y2_output_loss: 7.4769 - val_y1_output_root_mean_squared_error: 2.2200 - val_y2_output_root_mean_squared_error: 2.7534
# Epoch 20/500
# 614/614 [==============================] - 0s 136us/sample - loss: 18.5793 - y1_output_loss: 6.4933 - y2_output_loss: 11.9287 - y1_output_root_mean_squared_error: 2.5596 - y2_output_root_mean_squared_error: 3.4681 - val_loss: 13.1366 - val_y1_output_loss: 5.0450 - val_y2_output_loss: 7.7632 - val_y1_output_root_mean_squared_error: 2.2742 - val_y2_output_root_mean_squared_error: 2.8221
# Epoch 21/500
# 614/614 [==============================] - 0s 136us/sample - loss: 14.0212 - y1_output_loss: 5.4639 - y2_output_loss: 8.6567 - y1_output_root_mean_squared_error: 2.3297 - y2_output_root_mean_squared_error: 2.9315 - val_loss: 15.6621 - val_y1_output_loss: 6.2965 - val_y2_output_loss: 8.9786 - val_y1_output_root_mean_squared_error: 2.5283 - val_y2_output_root_mean_squared_error: 3.0446
# Epoch 22/500
# 614/614 [==============================] - 0s 132us/sample - loss: 14.1610 - y1_output_loss: 5.5920 - y2_output_loss: 8.6679 - y1_output_root_mean_squared_error: 2.3505 - y2_output_root_mean_squared_error: 2.9387 - val_loss: 15.3596 - val_y1_output_loss: 6.1364 - val_y2_output_loss: 8.7645 - val_y1_output_root_mean_squared_error: 2.5137 - val_y2_output_root_mean_squared_error: 3.0068
# Epoch 23/500
# 614/614 [==============================] - 0s 136us/sample - loss: 14.9501 - y1_output_loss: 5.6248 - y2_output_loss: 9.6306 - y1_output_root_mean_squared_error: 2.3672 - y2_output_root_mean_squared_error: 3.0572 - val_loss: 23.6488 - val_y1_output_loss: 6.3227 - val_y2_output_loss: 17.4322 - val_y1_output_root_mean_squared_error: 2.5454 - val_y2_output_root_mean_squared_error: 4.1436
# Epoch 24/500
# 614/614 [==============================] - 0s 135us/sample - loss: 14.1224 - y1_output_loss: 5.5216 - y2_output_loss: 8.5595 - y1_output_root_mean_squared_error: 2.3509 - y2_output_root_mean_squared_error: 2.9318 - val_loss: 17.4228 - val_y1_output_loss: 6.0831 - val_y2_output_loss: 11.2549 - val_y1_output_root_mean_squared_error: 2.4948 - val_y2_output_root_mean_squared_error: 3.3464
# Epoch 25/500
# 614/614 [==============================] - 0s 135us/sample - loss: 14.4237 - y1_output_loss: 5.5808 - y2_output_loss: 8.9225 - y1_output_root_mean_squared_error: 2.3650 - y2_output_root_mean_squared_error: 2.9716 - val_loss: 13.2479 - val_y1_output_loss: 5.3914 - val_y2_output_loss: 7.5117 - val_y1_output_root_mean_squared_error: 2.3529 - val_y2_output_root_mean_squared_error: 2.7770
# Epoch 26/500
# 614/614 [==============================] - 0s 134us/sample - loss: 13.0792 - y1_output_loss: 5.0070 - y2_output_loss: 7.9564 - y1_output_root_mean_squared_error: 2.2481 - y2_output_root_mean_squared_error: 2.8329 - val_loss: 12.9414 - val_y1_output_loss: 4.8016 - val_y2_output_loss: 7.7786 - val_y1_output_root_mean_squared_error: 2.2148 - val_y2_output_root_mean_squared_error: 2.8348
# Epoch 27/500
# 614/614 [==============================] - 0s 133us/sample - loss: 13.9950 - y1_output_loss: 5.4286 - y2_output_loss: 8.7160 - y1_output_root_mean_squared_error: 2.3263 - y2_output_root_mean_squared_error: 2.9297 - val_loss: 15.5487 - val_y1_output_loss: 4.7543 - val_y2_output_loss: 10.8981 - val_y1_output_root_mean_squared_error: 2.2081 - val_y2_output_root_mean_squared_error: 3.2670
# Epoch 28/500
# 614/614 [==============================] - 0s 133us/sample - loss: 15.3911 - y1_output_loss: 5.4092 - y2_output_loss: 9.8614 - y1_output_root_mean_squared_error: 2.3362 - y2_output_root_mean_squared_error: 3.1517 - val_loss: 12.1942 - val_y1_output_loss: 4.8115 - val_y2_output_loss: 7.1074 - val_y1_output_root_mean_squared_error: 2.2220 - val_y2_output_root_mean_squared_error: 2.6939
# Epoch 29/500
# 614/614 [==============================] - 0s 135us/sample - loss: 12.2322 - y1_output_loss: 4.9353 - y2_output_loss: 7.2812 - y1_output_root_mean_squared_error: 2.2125 - y2_output_root_mean_squared_error: 2.7087 - val_loss: 14.6253 - val_y1_output_loss: 5.7155 - val_y2_output_loss: 8.4907 - val_y1_output_root_mean_squared_error: 2.4119 - val_y2_output_root_mean_squared_error: 2.9679
# Epoch 30/500
# 614/614 [==============================] - 0s 132us/sample - loss: 12.8675 - y1_output_loss: 5.0010 - y2_output_loss: 7.8672 - y1_output_root_mean_squared_error: 2.2425 - y2_output_root_mean_squared_error: 2.7997 - val_loss: 12.4006 - val_y1_output_loss: 4.4044 - val_y2_output_loss: 7.6441 - val_y1_output_root_mean_squared_error: 2.1144 - val_y2_output_root_mean_squared_error: 2.8160
# Epoch 31/500
# 614/614 [==============================] - 0s 137us/sample - loss: 12.2578 - y1_output_loss: 4.7374 - y2_output_loss: 7.5078 - y1_output_root_mean_squared_error: 2.1663 - y2_output_root_mean_squared_error: 2.7504 - val_loss: 11.6225 - val_y1_output_loss: 4.4084 - val_y2_output_loss: 7.0764 - val_y1_output_root_mean_squared_error: 2.1206 - val_y2_output_root_mean_squared_error: 2.6694
# Epoch 32/500
# 614/614 [==============================] - 0s 132us/sample - loss: 12.2797 - y1_output_loss: 4.8343 - y2_output_loss: 7.4167 - y1_output_root_mean_squared_error: 2.2028 - y2_output_root_mean_squared_error: 2.7253 - val_loss: 21.1180 - val_y1_output_loss: 6.6014 - val_y2_output_loss: 14.5026 - val_y1_output_root_mean_squared_error: 2.6018 - val_y2_output_root_mean_squared_error: 3.7879
# Epoch 33/500
# 614/614 [==============================] - 0s 132us/sample - loss: 13.1637 - y1_output_loss: 4.7723 - y2_output_loss: 8.2846 - y1_output_root_mean_squared_error: 2.1928 - y2_output_root_mean_squared_error: 2.8905 - val_loss: 10.2030 - val_y1_output_loss: 4.0893 - val_y2_output_loss: 5.8576 - val_y1_output_root_mean_squared_error: 2.0385 - val_y2_output_root_mean_squared_error: 2.4592
# Epoch 34/500
# 614/614 [==============================] - 0s 134us/sample - loss: 15.5301 - y1_output_loss: 5.0016 - y2_output_loss: 10.4920 - y1_output_root_mean_squared_error: 2.2270 - y2_output_root_mean_squared_error: 3.2513 - val_loss: 18.2086 - val_y1_output_loss: 6.1388 - val_y2_output_loss: 11.6263 - val_y1_output_root_mean_squared_error: 2.4860 - val_y2_output_root_mean_squared_error: 3.4682
# Epoch 35/500
# 614/614 [==============================] - 0s 132us/sample - loss: 12.1690 - y1_output_loss: 4.5263 - y2_output_loss: 7.6835 - y1_output_root_mean_squared_error: 2.1369 - y2_output_root_mean_squared_error: 2.7573 - val_loss: 15.5474 - val_y1_output_loss: 5.0704 - val_y2_output_loss: 10.8301 - val_y1_output_root_mean_squared_error: 2.2556 - val_y2_output_root_mean_squared_error: 3.2342
# Epoch 36/500
# 614/614 [==============================] - 0s 140us/sample - loss: 10.6852 - y1_output_loss: 4.1821 - y2_output_loss: 6.5543 - y1_output_root_mean_squared_error: 2.0428 - y2_output_root_mean_squared_error: 2.5519 - val_loss: 22.8860 - val_y1_output_loss: 7.0443 - val_y2_output_loss: 15.5478 - val_y1_output_root_mean_squared_error: 2.6489 - val_y2_output_root_mean_squared_error: 3.9836
# Epoch 37/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.7872 - y1_output_loss: 4.2364 - y2_output_loss: 7.5233 - y1_output_root_mean_squared_error: 2.0570 - y2_output_root_mean_squared_error: 2.7488 - val_loss: 13.7385 - val_y1_output_loss: 6.4622 - val_y2_output_loss: 7.2268 - val_y1_output_root_mean_squared_error: 2.5568 - val_y2_output_root_mean_squared_error: 2.6835
# Epoch 38/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.6703 - y1_output_loss: 4.2987 - y2_output_loss: 7.4711 - y1_output_root_mean_squared_error: 2.0695 - y2_output_root_mean_squared_error: 2.7180 - val_loss: 27.0503 - val_y1_output_loss: 7.3853 - val_y2_output_loss: 20.3353 - val_y1_output_root_mean_squared_error: 2.7136 - val_y2_output_root_mean_squared_error: 4.4369
# Epoch 39/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.0545 - y1_output_loss: 3.7737 - y2_output_loss: 6.2584 - y1_output_root_mean_squared_error: 1.9469 - y2_output_root_mean_squared_error: 2.5028 - val_loss: 9.3039 - val_y1_output_loss: 3.8206 - val_y2_output_loss: 5.3322 - val_y1_output_root_mean_squared_error: 1.9729 - val_y2_output_root_mean_squared_error: 2.3263
# Epoch 40/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.2570 - y1_output_loss: 3.8738 - y2_output_loss: 7.3473 - y1_output_root_mean_squared_error: 1.9729 - y2_output_root_mean_squared_error: 2.7138 - val_loss: 8.3292 - val_y1_output_loss: 3.0071 - val_y2_output_loss: 5.1460 - val_y1_output_root_mean_squared_error: 1.7459 - val_y2_output_root_mean_squared_error: 2.2980
# Epoch 41/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.8389 - y1_output_loss: 3.4194 - y2_output_loss: 6.3474 - y1_output_root_mean_squared_error: 1.8523 - y2_output_root_mean_squared_error: 2.5314 - val_loss: 10.0481 - val_y1_output_loss: 3.1653 - val_y2_output_loss: 6.9257 - val_y1_output_root_mean_squared_error: 1.7964 - val_y2_output_root_mean_squared_error: 2.6117
# Epoch 42/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.9942 - y1_output_loss: 3.3828 - y2_output_loss: 5.5555 - y1_output_root_mean_squared_error: 1.8457 - y2_output_root_mean_squared_error: 2.3638 - val_loss: 13.2038 - val_y1_output_loss: 3.9282 - val_y2_output_loss: 8.9862 - val_y1_output_root_mean_squared_error: 1.9838 - val_y2_output_root_mean_squared_error: 3.0444
# Epoch 43/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.9189 - y1_output_loss: 3.0263 - y2_output_loss: 5.8153 - y1_output_root_mean_squared_error: 1.7469 - y2_output_root_mean_squared_error: 2.4222 - val_loss: 7.6111 - val_y1_output_loss: 2.6971 - val_y2_output_loss: 4.7430 - val_y1_output_root_mean_squared_error: 1.6496 - val_y2_output_root_mean_squared_error: 2.2113
# Epoch 44/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.2582 - y1_output_loss: 3.5196 - y2_output_loss: 6.7355 - y1_output_root_mean_squared_error: 1.8821 - y2_output_root_mean_squared_error: 2.5915 - val_loss: 9.3600 - val_y1_output_loss: 2.9176 - val_y2_output_loss: 6.1833 - val_y1_output_root_mean_squared_error: 1.7230 - val_y2_output_root_mean_squared_error: 2.5281
# Epoch 45/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.8382 - y1_output_loss: 2.8839 - y2_output_loss: 4.9002 - y1_output_root_mean_squared_error: 1.7049 - y2_output_root_mean_squared_error: 2.2207 - val_loss: 8.6431 - val_y1_output_loss: 2.4930 - val_y2_output_loss: 5.9363 - val_y1_output_root_mean_squared_error: 1.5843 - val_y2_output_root_mean_squared_error: 2.4765
# Epoch 46/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.4991 - y1_output_loss: 2.7155 - y2_output_loss: 4.7366 - y1_output_root_mean_squared_error: 1.6546 - y2_output_root_mean_squared_error: 2.1821 - val_loss: 9.7977 - val_y1_output_loss: 3.0128 - val_y2_output_loss: 6.5264 - val_y1_output_root_mean_squared_error: 1.7418 - val_y2_output_root_mean_squared_error: 2.6008
# Epoch 47/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.2845 - y1_output_loss: 2.4772 - y2_output_loss: 4.8746 - y1_output_root_mean_squared_error: 1.5707 - y2_output_root_mean_squared_error: 2.1949 - val_loss: 10.5906 - val_y1_output_loss: 3.6769 - val_y2_output_loss: 6.7931 - val_y1_output_root_mean_squared_error: 1.8988 - val_y2_output_root_mean_squared_error: 2.6429
# Epoch 48/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.7462 - y1_output_loss: 2.8553 - y2_output_loss: 4.9858 - y1_output_root_mean_squared_error: 1.6606 - y2_output_root_mean_squared_error: 2.2335 - val_loss: 28.0530 - val_y1_output_loss: 11.0411 - val_y2_output_loss: 17.0606 - val_y1_output_root_mean_squared_error: 3.2806 - val_y2_output_root_mean_squared_error: 4.1582
# Epoch 49/500
# 614/614 [==============================] - 0s 136us/sample - loss: 9.6612 - y1_output_loss: 3.0355 - y2_output_loss: 6.6347 - y1_output_root_mean_squared_error: 1.7326 - y2_output_root_mean_squared_error: 2.5805 - val_loss: 12.2415 - val_y1_output_loss: 2.3218 - val_y2_output_loss: 9.6560 - val_y1_output_root_mean_squared_error: 1.5260 - val_y2_output_root_mean_squared_error: 3.1485
# Epoch 50/500
# 614/614 [==============================] - 0s 141us/sample - loss: 8.4101 - y1_output_loss: 2.7386 - y2_output_loss: 5.6396 - y1_output_root_mean_squared_error: 1.6617 - y2_output_root_mean_squared_error: 2.3767 - val_loss: 11.1847 - val_y1_output_loss: 2.9263 - val_y2_output_loss: 8.1139 - val_y1_output_root_mean_squared_error: 1.7025 - val_y2_output_root_mean_squared_error: 2.8785
# Epoch 51/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.9008 - y1_output_loss: 2.6572 - y2_output_loss: 5.1721 - y1_output_root_mean_squared_error: 1.6372 - y2_output_root_mean_squared_error: 2.2848 - val_loss: 8.0557 - val_y1_output_loss: 2.1091 - val_y2_output_loss: 5.7265 - val_y1_output_root_mean_squared_error: 1.4581 - val_y2_output_root_mean_squared_error: 2.4351
# Epoch 52/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.9391 - y1_output_loss: 2.7632 - y2_output_loss: 6.1096 - y1_output_root_mean_squared_error: 1.6692 - y2_output_root_mean_squared_error: 2.4805 - val_loss: 6.1659 - val_y1_output_loss: 1.9646 - val_y2_output_loss: 4.0671 - val_y1_output_root_mean_squared_error: 1.4195 - val_y2_output_root_mean_squared_error: 2.0374
# Epoch 53/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.2949 - y1_output_loss: 2.7267 - y2_output_loss: 5.6982 - y1_output_root_mean_squared_error: 1.6307 - y2_output_root_mean_squared_error: 2.3739 - val_loss: 24.4672 - val_y1_output_loss: 6.4124 - val_y2_output_loss: 17.8943 - val_y1_output_root_mean_squared_error: 2.5073 - val_y2_output_root_mean_squared_error: 4.2639
# Epoch 54/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.6640 - y1_output_loss: 2.5525 - y2_output_loss: 5.0813 - y1_output_root_mean_squared_error: 1.5987 - y2_output_root_mean_squared_error: 2.2601 - val_loss: 13.2153 - val_y1_output_loss: 3.7890 - val_y2_output_loss: 9.2470 - val_y1_output_root_mean_squared_error: 1.9360 - val_y2_output_root_mean_squared_error: 3.0769
# Epoch 55/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.8096 - y1_output_loss: 2.1678 - y2_output_loss: 4.6438 - y1_output_root_mean_squared_error: 1.4777 - y2_output_root_mean_squared_error: 2.1508 - val_loss: 8.3499 - val_y1_output_loss: 2.5403 - val_y2_output_loss: 5.8270 - val_y1_output_root_mean_squared_error: 1.6154 - val_y2_output_root_mean_squared_error: 2.3959
# Epoch 56/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.0171 - y1_output_loss: 2.2549 - y2_output_loss: 4.7119 - y1_output_root_mean_squared_error: 1.5043 - y2_output_root_mean_squared_error: 2.1804 - val_loss: 5.6126 - val_y1_output_loss: 1.7970 - val_y2_output_loss: 3.6862 - val_y1_output_root_mean_squared_error: 1.3568 - val_y2_output_root_mean_squared_error: 1.9421
# Epoch 57/500
# 614/614 [==============================] - 0s 133us/sample - loss: 22.4619 - y1_output_loss: 7.4850 - y2_output_loss: 14.8149 - y1_output_root_mean_squared_error: 2.7459 - y2_output_root_mean_squared_error: 3.8629 - val_loss: 9.9972 - val_y1_output_loss: 2.4477 - val_y2_output_loss: 7.2938 - val_y1_output_root_mean_squared_error: 1.5665 - val_y2_output_root_mean_squared_error: 2.7465
# Epoch 58/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.8023 - y1_output_loss: 2.4087 - y2_output_loss: 5.3451 - y1_output_root_mean_squared_error: 1.5549 - y2_output_root_mean_squared_error: 2.3205 - val_loss: 8.9066 - val_y1_output_loss: 1.9591 - val_y2_output_loss: 6.7336 - val_y1_output_root_mean_squared_error: 1.4034 - val_y2_output_root_mean_squared_error: 2.6339
# Epoch 59/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.5135 - y1_output_loss: 2.2662 - y2_output_loss: 5.3877 - y1_output_root_mean_squared_error: 1.5121 - y2_output_root_mean_squared_error: 2.2863 - val_loss: 44.8965 - val_y1_output_loss: 7.7935 - val_y2_output_loss: 38.6255 - val_y1_output_root_mean_squared_error: 2.7688 - val_y2_output_root_mean_squared_error: 6.1016
# Epoch 60/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.9953 - y1_output_loss: 3.4464 - y2_output_loss: 7.4939 - y1_output_root_mean_squared_error: 1.8585 - y2_output_root_mean_squared_error: 2.7462 - val_loss: 10.7721 - val_y1_output_loss: 3.7279 - val_y2_output_loss: 6.8038 - val_y1_output_root_mean_squared_error: 1.9362 - val_y2_output_root_mean_squared_error: 2.6501
# Epoch 61/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.8757 - y1_output_loss: 2.2569 - y2_output_loss: 4.6053 - y1_output_root_mean_squared_error: 1.5022 - y2_output_root_mean_squared_error: 2.1492 - val_loss: 10.5512 - val_y1_output_loss: 2.9835 - val_y2_output_loss: 7.4148 - val_y1_output_root_mean_squared_error: 1.7264 - val_y2_output_root_mean_squared_error: 2.7515
# Epoch 62/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.2148 - y1_output_loss: 2.0352 - y2_output_loss: 4.1403 - y1_output_root_mean_squared_error: 1.4299 - y2_output_root_mean_squared_error: 2.0421 - val_loss: 9.2362 - val_y1_output_loss: 2.7078 - val_y2_output_loss: 6.2766 - val_y1_output_root_mean_squared_error: 1.6539 - val_y2_output_root_mean_squared_error: 2.5497
# Epoch 63/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.2153 - y1_output_loss: 1.9647 - y2_output_loss: 4.2310 - y1_output_root_mean_squared_error: 1.4055 - y2_output_root_mean_squared_error: 2.0591 - val_loss: 6.1413 - val_y1_output_loss: 2.1270 - val_y2_output_loss: 4.0064 - val_y1_output_root_mean_squared_error: 1.4327 - val_y2_output_root_mean_squared_error: 2.0220
# Epoch 64/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.4984 - y1_output_loss: 2.2202 - y2_output_loss: 5.2346 - y1_output_root_mean_squared_error: 1.4931 - y2_output_root_mean_squared_error: 2.2955 - val_loss: 5.6995 - val_y1_output_loss: 1.7168 - val_y2_output_loss: 3.9453 - val_y1_output_root_mean_squared_error: 1.3095 - val_y2_output_root_mean_squared_error: 1.9962
# Epoch 65/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.1409 - y1_output_loss: 1.9626 - y2_output_loss: 4.1282 - y1_output_root_mean_squared_error: 1.4062 - y2_output_root_mean_squared_error: 2.0405 - val_loss: 5.8212 - val_y1_output_loss: 1.5694 - val_y2_output_loss: 4.1464 - val_y1_output_root_mean_squared_error: 1.2459 - val_y2_output_root_mean_squared_error: 2.0661
# Epoch 66/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.9957 - y1_output_loss: 2.1149 - y2_output_loss: 4.8881 - y1_output_root_mean_squared_error: 1.4497 - y2_output_root_mean_squared_error: 2.2123 - val_loss: 11.3836 - val_y1_output_loss: 2.4173 - val_y2_output_loss: 8.7692 - val_y1_output_root_mean_squared_error: 1.5428 - val_y2_output_root_mean_squared_error: 3.0006
# Epoch 67/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.2048 - y1_output_loss: 1.8875 - y2_output_loss: 4.2797 - y1_output_root_mean_squared_error: 1.3763 - y2_output_root_mean_squared_error: 2.0762 - val_loss: 7.6651 - val_y1_output_loss: 2.0410 - val_y2_output_loss: 5.4290 - val_y1_output_root_mean_squared_error: 1.4356 - val_y2_output_root_mean_squared_error: 2.3673
# Epoch 68/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.9390 - y1_output_loss: 2.3643 - y2_output_loss: 5.5900 - y1_output_root_mean_squared_error: 1.5317 - y2_output_root_mean_squared_error: 2.3649 - val_loss: 5.1287 - val_y1_output_loss: 1.4946 - val_y2_output_loss: 3.5461 - val_y1_output_root_mean_squared_error: 1.2226 - val_y2_output_root_mean_squared_error: 1.9063
# Epoch 69/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.3086 - y1_output_loss: 1.5512 - y2_output_loss: 3.7152 - y1_output_root_mean_squared_error: 1.2499 - y2_output_root_mean_squared_error: 1.9355 - val_loss: 7.0976 - val_y1_output_loss: 2.0090 - val_y2_output_loss: 5.0080 - val_y1_output_root_mean_squared_error: 1.3982 - val_y2_output_root_mean_squared_error: 2.2678
# Epoch 70/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.6038 - y1_output_loss: 1.7133 - y2_output_loss: 3.9030 - y1_output_root_mean_squared_error: 1.3040 - y2_output_root_mean_squared_error: 1.9757 - val_loss: 12.9044 - val_y1_output_loss: 4.5172 - val_y2_output_loss: 8.6142 - val_y1_output_root_mean_squared_error: 2.1293 - val_y2_output_root_mean_squared_error: 2.8932
# Epoch 71/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.9916 - y1_output_loss: 1.6385 - y2_output_loss: 3.3817 - y1_output_root_mean_squared_error: 1.2757 - y2_output_root_mean_squared_error: 1.8342 - val_loss: 4.7188 - val_y1_output_loss: 1.2844 - val_y2_output_loss: 3.4084 - val_y1_output_root_mean_squared_error: 1.1350 - val_y2_output_root_mean_squared_error: 1.8522
# Epoch 72/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.3823 - y1_output_loss: 1.5239 - y2_output_loss: 3.8769 - y1_output_root_mean_squared_error: 1.2351 - y2_output_root_mean_squared_error: 1.9639 - val_loss: 15.9547 - val_y1_output_loss: 2.7821 - val_y2_output_loss: 13.0690 - val_y1_output_root_mean_squared_error: 1.6391 - val_y2_output_root_mean_squared_error: 3.6425
# Epoch 73/500
# 614/614 [==============================] - 0s 157us/sample - loss: 5.3555 - y1_output_loss: 1.5785 - y2_output_loss: 3.7928 - y1_output_root_mean_squared_error: 1.2589 - y2_output_root_mean_squared_error: 1.9418 - val_loss: 13.2198 - val_y1_output_loss: 3.1687 - val_y2_output_loss: 10.2569 - val_y1_output_root_mean_squared_error: 1.7907 - val_y2_output_root_mean_squared_error: 3.1644
# Epoch 74/500
# 614/614 [==============================] - 0s 155us/sample - loss: 7.0821 - y1_output_loss: 2.2278 - y2_output_loss: 4.8471 - y1_output_root_mean_squared_error: 1.4923 - y2_output_root_mean_squared_error: 2.2034 - val_loss: 4.8676 - val_y1_output_loss: 1.3309 - val_y2_output_loss: 3.4694 - val_y1_output_root_mean_squared_error: 1.1576 - val_y2_output_root_mean_squared_error: 1.8782
# Epoch 75/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.7464 - y1_output_loss: 1.5098 - y2_output_loss: 3.2018 - y1_output_root_mean_squared_error: 1.2309 - y2_output_root_mean_squared_error: 1.7975 - val_loss: 5.5948 - val_y1_output_loss: 1.6654 - val_y2_output_loss: 3.8347 - val_y1_output_root_mean_squared_error: 1.2769 - val_y2_output_root_mean_squared_error: 1.9911
# Epoch 76/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.3309 - y1_output_loss: 1.6948 - y2_output_loss: 4.5823 - y1_output_root_mean_squared_error: 1.3070 - y2_output_root_mean_squared_error: 2.1500 - val_loss: 4.3964 - val_y1_output_loss: 1.1685 - val_y2_output_loss: 3.1599 - val_y1_output_root_mean_squared_error: 1.0843 - val_y2_output_root_mean_squared_error: 1.7946
# Epoch 77/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.2177 - y1_output_loss: 1.8702 - y2_output_loss: 4.2973 - y1_output_root_mean_squared_error: 1.3740 - y2_output_root_mean_squared_error: 2.0809 - val_loss: 4.4276 - val_y1_output_loss: 1.0834 - val_y2_output_loss: 3.2870 - val_y1_output_root_mean_squared_error: 1.0414 - val_y2_output_root_mean_squared_error: 1.8284
# Epoch 78/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.4575 - y1_output_loss: 1.3033 - y2_output_loss: 3.1587 - y1_output_root_mean_squared_error: 1.1344 - y2_output_root_mean_squared_error: 1.7806 - val_loss: 4.3607 - val_y1_output_loss: 1.2596 - val_y2_output_loss: 3.0181 - val_y1_output_root_mean_squared_error: 1.1308 - val_y2_output_root_mean_squared_error: 1.7556
# Epoch 79/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.7072 - y1_output_loss: 1.2803 - y2_output_loss: 3.3965 - y1_output_root_mean_squared_error: 1.1351 - y2_output_root_mean_squared_error: 1.8490 - val_loss: 6.8612 - val_y1_output_loss: 1.2704 - val_y2_output_loss: 5.4800 - val_y1_output_root_mean_squared_error: 1.1090 - val_y2_output_root_mean_squared_error: 2.3730
# Epoch 80/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.8449 - y1_output_loss: 0.9947 - y2_output_loss: 2.8293 - y1_output_root_mean_squared_error: 1.0015 - y2_output_root_mean_squared_error: 1.6858 - val_loss: 4.3428 - val_y1_output_loss: 1.1754 - val_y2_output_loss: 3.1484 - val_y1_output_root_mean_squared_error: 1.0725 - val_y2_output_root_mean_squared_error: 1.7867
# Epoch 81/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.2832 - y1_output_loss: 1.0978 - y2_output_loss: 3.1915 - y1_output_root_mean_squared_error: 1.0506 - y2_output_root_mean_squared_error: 1.7831 - val_loss: 6.2065 - val_y1_output_loss: 1.1887 - val_y2_output_loss: 4.9048 - val_y1_output_root_mean_squared_error: 1.0777 - val_y2_output_root_mean_squared_error: 2.2461
# Epoch 82/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.6974 - y1_output_loss: 1.3448 - y2_output_loss: 3.3427 - y1_output_root_mean_squared_error: 1.1618 - y2_output_root_mean_squared_error: 1.8297 - val_loss: 3.7979 - val_y1_output_loss: 1.0951 - val_y2_output_loss: 2.7139 - val_y1_output_root_mean_squared_error: 1.0270 - val_y2_output_root_mean_squared_error: 1.6562
# Epoch 83/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.0562 - y1_output_loss: 1.1134 - y2_output_loss: 2.9256 - y1_output_root_mean_squared_error: 1.0587 - y2_output_root_mean_squared_error: 1.7133 - val_loss: 3.7982 - val_y1_output_loss: 0.8122 - val_y2_output_loss: 3.0415 - val_y1_output_root_mean_squared_error: 0.8820 - val_y2_output_root_mean_squared_error: 1.7379
# Epoch 84/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.2731 - y1_output_loss: 1.1437 - y2_output_loss: 3.0980 - y1_output_root_mean_squared_error: 1.0738 - y2_output_root_mean_squared_error: 1.7663 - val_loss: 3.9223 - val_y1_output_loss: 0.9365 - val_y2_output_loss: 3.0475 - val_y1_output_root_mean_squared_error: 0.9533 - val_y2_output_root_mean_squared_error: 1.7359
# Epoch 85/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.6625 - y1_output_loss: 1.4371 - y2_output_loss: 3.2045 - y1_output_root_mean_squared_error: 1.2000 - y2_output_root_mean_squared_error: 1.7951 - val_loss: 4.0080 - val_y1_output_loss: 0.7964 - val_y2_output_loss: 3.1625 - val_y1_output_root_mean_squared_error: 0.8883 - val_y2_output_root_mean_squared_error: 1.7941
# Epoch 86/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.5355 - y1_output_loss: 2.8658 - y2_output_loss: 6.6148 - y1_output_root_mean_squared_error: 1.6993 - y2_output_root_mean_squared_error: 2.5783 - val_loss: 9.0721 - val_y1_output_loss: 0.9381 - val_y2_output_loss: 7.9200 - val_y1_output_root_mean_squared_error: 0.9618 - val_y2_output_root_mean_squared_error: 2.8543
# Epoch 87/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.7218 - y1_output_loss: 0.9016 - y2_output_loss: 2.7889 - y1_output_root_mean_squared_error: 0.9533 - y2_output_root_mean_squared_error: 1.6772 - val_loss: 3.6874 - val_y1_output_loss: 0.7884 - val_y2_output_loss: 2.9147 - val_y1_output_root_mean_squared_error: 0.8842 - val_y2_output_root_mean_squared_error: 1.7046
# Epoch 88/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.7281 - y1_output_loss: 0.7380 - y2_output_loss: 1.9902 - y1_output_root_mean_squared_error: 0.8609 - y2_output_root_mean_squared_error: 1.4096 - val_loss: 5.9416 - val_y1_output_loss: 1.0226 - val_y2_output_loss: 5.1005 - val_y1_output_root_mean_squared_error: 1.0099 - val_y2_output_root_mean_squared_error: 2.2185
# Epoch 89/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.4910 - y1_output_loss: 0.9042 - y2_output_loss: 2.5667 - y1_output_root_mean_squared_error: 0.9551 - y2_output_root_mean_squared_error: 1.6058 - val_loss: 3.3960 - val_y1_output_loss: 0.6826 - val_y2_output_loss: 2.7239 - val_y1_output_root_mean_squared_error: 0.8080 - val_y2_output_root_mean_squared_error: 1.6563
# Epoch 90/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.8475 - y1_output_loss: 0.6847 - y2_output_loss: 2.1827 - y1_output_root_mean_squared_error: 0.8208 - y2_output_root_mean_squared_error: 1.4743 - val_loss: 4.7013 - val_y1_output_loss: 0.6835 - val_y2_output_loss: 4.1709 - val_y1_output_root_mean_squared_error: 0.8230 - val_y2_output_root_mean_squared_error: 2.0060
# Epoch 91/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.1676 - y1_output_loss: 0.7647 - y2_output_loss: 2.3783 - y1_output_root_mean_squared_error: 0.8781 - y2_output_root_mean_squared_error: 1.5481 - val_loss: 5.8062 - val_y1_output_loss: 1.1311 - val_y2_output_loss: 4.5869 - val_y1_output_root_mean_squared_error: 1.0465 - val_y2_output_root_mean_squared_error: 2.1705
# Epoch 92/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.6458 - y1_output_loss: 0.7109 - y2_output_loss: 1.9604 - y1_output_root_mean_squared_error: 0.8463 - y2_output_root_mean_squared_error: 1.3891 - val_loss: 7.6890 - val_y1_output_loss: 0.7124 - val_y2_output_loss: 6.8345 - val_y1_output_root_mean_squared_error: 0.8228 - val_y2_output_root_mean_squared_error: 2.6480
# Epoch 93/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.8427 - y1_output_loss: 0.7311 - y2_output_loss: 2.0983 - y1_output_root_mean_squared_error: 0.8584 - y2_output_root_mean_squared_error: 1.4511 - val_loss: 3.2488 - val_y1_output_loss: 0.6033 - val_y2_output_loss: 2.6814 - val_y1_output_root_mean_squared_error: 0.7559 - val_y2_output_root_mean_squared_error: 1.6363
# Epoch 94/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.7445 - y1_output_loss: 0.6028 - y2_output_loss: 2.1181 - y1_output_root_mean_squared_error: 0.7792 - y2_output_root_mean_squared_error: 1.4620 - val_loss: 3.1489 - val_y1_output_loss: 0.6227 - val_y2_output_loss: 2.5151 - val_y1_output_root_mean_squared_error: 0.7689 - val_y2_output_root_mean_squared_error: 1.5993
# Epoch 95/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.0612 - y1_output_loss: 0.7417 - y2_output_loss: 2.3423 - y1_output_root_mean_squared_error: 0.8637 - y2_output_root_mean_squared_error: 1.5216 - val_loss: 5.8626 - val_y1_output_loss: 0.7768 - val_y2_output_loss: 5.0678 - val_y1_output_root_mean_squared_error: 0.8439 - val_y2_output_root_mean_squared_error: 2.2694
# Epoch 96/500
# 614/614 [==============================] - 0s 191us/sample - loss: 5.2674 - y1_output_loss: 1.3490 - y2_output_loss: 3.8762 - y1_output_root_mean_squared_error: 1.1670 - y2_output_root_mean_squared_error: 1.9762 - val_loss: 4.5214 - val_y1_output_loss: 0.9374 - val_y2_output_loss: 3.5799 - val_y1_output_root_mean_squared_error: 0.9715 - val_y2_output_root_mean_squared_error: 1.8915
# Epoch 97/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.9919 - y1_output_loss: 0.7121 - y2_output_loss: 2.2546 - y1_output_root_mean_squared_error: 0.8479 - y2_output_root_mean_squared_error: 1.5077 - val_loss: 3.2667 - val_y1_output_loss: 0.6268 - val_y2_output_loss: 2.6418 - val_y1_output_root_mean_squared_error: 0.7853 - val_y2_output_root_mean_squared_error: 1.6279
# Epoch 98/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.4421 - y1_output_loss: 0.7738 - y2_output_loss: 2.6508 - y1_output_root_mean_squared_error: 0.8808 - y2_output_root_mean_squared_error: 1.6329 - val_loss: 3.5393 - val_y1_output_loss: 0.6715 - val_y2_output_loss: 2.8379 - val_y1_output_root_mean_squared_error: 0.8070 - val_y2_output_root_mean_squared_error: 1.6994
# Epoch 99/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.6776 - y1_output_loss: 1.0831 - y2_output_loss: 3.6116 - y1_output_root_mean_squared_error: 1.0425 - y2_output_root_mean_squared_error: 1.8949 - val_loss: 12.5309 - val_y1_output_loss: 2.5414 - val_y2_output_loss: 10.4129 - val_y1_output_root_mean_squared_error: 1.4918 - val_y2_output_root_mean_squared_error: 3.2102
# Epoch 100/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.9188 - y1_output_loss: 0.6892 - y2_output_loss: 2.2159 - y1_output_root_mean_squared_error: 0.8308 - y2_output_root_mean_squared_error: 1.4928 - val_loss: 2.9469 - val_y1_output_loss: 0.7022 - val_y2_output_loss: 2.2649 - val_y1_output_root_mean_squared_error: 0.8115 - val_y2_output_root_mean_squared_error: 1.5128
# Epoch 101/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.7463 - y1_output_loss: 0.6021 - y2_output_loss: 2.1301 - y1_output_root_mean_squared_error: 0.7761 - y2_output_root_mean_squared_error: 1.4642 - val_loss: 3.3745 - val_y1_output_loss: 0.5819 - val_y2_output_loss: 2.8849 - val_y1_output_root_mean_squared_error: 0.7392 - val_y2_output_root_mean_squared_error: 1.6817
# Epoch 102/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.6981 - y1_output_loss: 0.6434 - y2_output_loss: 2.0331 - y1_output_root_mean_squared_error: 0.8057 - y2_output_root_mean_squared_error: 1.4314 - val_loss: 3.5908 - val_y1_output_loss: 0.6286 - val_y2_output_loss: 2.9091 - val_y1_output_root_mean_squared_error: 0.7831 - val_y2_output_root_mean_squared_error: 1.7255
# Epoch 103/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.6618 - y1_output_loss: 0.6164 - y2_output_loss: 2.0353 - y1_output_root_mean_squared_error: 0.7868 - y2_output_root_mean_squared_error: 1.4293 - val_loss: 3.0852 - val_y1_output_loss: 0.6631 - val_y2_output_loss: 2.4272 - val_y1_output_root_mean_squared_error: 0.7875 - val_y2_output_root_mean_squared_error: 1.5700
# Epoch 104/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.6872 - y1_output_loss: 0.6400 - y2_output_loss: 2.0429 - y1_output_root_mean_squared_error: 0.7984 - y2_output_root_mean_squared_error: 1.4317 - val_loss: 9.1676 - val_y1_output_loss: 3.4298 - val_y2_output_loss: 5.9360 - val_y1_output_root_mean_squared_error: 1.8489 - val_y2_output_root_mean_squared_error: 2.3978
# Epoch 105/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.9203 - y1_output_loss: 0.7025 - y2_output_loss: 2.2633 - y1_output_root_mean_squared_error: 0.8418 - y2_output_root_mean_squared_error: 1.4872 - val_loss: 3.7334 - val_y1_output_loss: 0.5916 - val_y2_output_loss: 3.0608 - val_y1_output_root_mean_squared_error: 0.7590 - val_y2_output_root_mean_squared_error: 1.7769
# Epoch 106/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.2292 - y1_output_loss: 0.4795 - y2_output_loss: 1.7610 - y1_output_root_mean_squared_error: 0.6921 - y2_output_root_mean_squared_error: 1.3229 - val_loss: 5.5474 - val_y1_output_loss: 0.7695 - val_y2_output_loss: 4.7791 - val_y1_output_root_mean_squared_error: 0.8332 - val_y2_output_root_mean_squared_error: 2.2030
# Epoch 107/500
# 614/614 [==============================] - 0s 135us/sample - loss: 13.8291 - y1_output_loss: 5.0851 - y2_output_loss: 8.6199 - y1_output_root_mean_squared_error: 2.2646 - y2_output_root_mean_squared_error: 2.9497 - val_loss: 3.4156 - val_y1_output_loss: 0.5551 - val_y2_output_loss: 2.9518 - val_y1_output_root_mean_squared_error: 0.7312 - val_y2_output_root_mean_squared_error: 1.6973
# Epoch 108/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.5548 - y1_output_loss: 0.6457 - y2_output_loss: 1.9366 - y1_output_root_mean_squared_error: 0.8026 - y2_output_root_mean_squared_error: 1.3823 - val_loss: 14.3819 - val_y1_output_loss: 3.0298 - val_y2_output_loss: 11.3585 - val_y1_output_root_mean_squared_error: 1.6995 - val_y2_output_root_mean_squared_error: 3.3902
# Epoch 109/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.2543 - y1_output_loss: 0.5765 - y2_output_loss: 1.6570 - y1_output_root_mean_squared_error: 0.7626 - y2_output_root_mean_squared_error: 1.2934 - val_loss: 3.0383 - val_y1_output_loss: 0.4599 - val_y2_output_loss: 2.5243 - val_y1_output_root_mean_squared_error: 0.6715 - val_y2_output_root_mean_squared_error: 1.6086
# Epoch 110/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.1006 - y1_output_loss: 0.4754 - y2_output_loss: 1.6283 - y1_output_root_mean_squared_error: 0.6910 - y2_output_root_mean_squared_error: 1.2740 - val_loss: 3.0605 - val_y1_output_loss: 0.4772 - val_y2_output_loss: 2.5658 - val_y1_output_root_mean_squared_error: 0.6820 - val_y2_output_root_mean_squared_error: 1.6110
# Epoch 111/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.5723 - y1_output_loss: 0.6847 - y2_output_loss: 1.9131 - y1_output_root_mean_squared_error: 0.8275 - y2_output_root_mean_squared_error: 1.3739 - val_loss: 7.1962 - val_y1_output_loss: 0.7497 - val_y2_output_loss: 6.5811 - val_y1_output_root_mean_squared_error: 0.8641 - val_y2_output_root_mean_squared_error: 2.5396
# Epoch 112/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.3769 - y1_output_loss: 0.5288 - y2_output_loss: 1.8352 - y1_output_root_mean_squared_error: 0.7295 - y2_output_root_mean_squared_error: 1.3582 - val_loss: 3.4607 - val_y1_output_loss: 0.7344 - val_y2_output_loss: 2.7128 - val_y1_output_root_mean_squared_error: 0.8335 - val_y2_output_root_mean_squared_error: 1.6631
# Epoch 113/500
# 614/614 [==============================] - 0s 157us/sample - loss: 2.6099 - y1_output_loss: 0.5862 - y2_output_loss: 2.0125 - y1_output_root_mean_squared_error: 0.7657 - y2_output_root_mean_squared_error: 1.4226 - val_loss: 4.5000 - val_y1_output_loss: 0.6342 - val_y2_output_loss: 3.7697 - val_y1_output_root_mean_squared_error: 0.7861 - val_y2_output_root_mean_squared_error: 1.9703
# Epoch 114/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.4876 - y1_output_loss: 0.5691 - y2_output_loss: 1.9068 - y1_output_root_mean_squared_error: 0.7530 - y2_output_root_mean_squared_error: 1.3859 - val_loss: 3.6491 - val_y1_output_loss: 0.6917 - val_y2_output_loss: 2.9487 - val_y1_output_root_mean_squared_error: 0.8037 - val_y2_output_root_mean_squared_error: 1.7330
# Epoch 115/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.1234 - y1_output_loss: 0.4950 - y2_output_loss: 1.6088 - y1_output_root_mean_squared_error: 0.7066 - y2_output_root_mean_squared_error: 1.2744 - val_loss: 2.9060 - val_y1_output_loss: 0.5057 - val_y2_output_loss: 2.4440 - val_y1_output_root_mean_squared_error: 0.7039 - val_y2_output_root_mean_squared_error: 1.5526
# Epoch 116/500
# 614/614 [==============================] - 0s 187us/sample - loss: 2.1251 - y1_output_loss: 0.4682 - y2_output_loss: 1.6973 - y1_output_root_mean_squared_error: 0.6791 - y2_output_root_mean_squared_error: 1.2900 - val_loss: 11.4220 - val_y1_output_loss: 2.0993 - val_y2_output_loss: 9.2011 - val_y1_output_root_mean_squared_error: 1.4277 - val_y2_output_root_mean_squared_error: 3.0633
# Epoch 117/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.4312 - y1_output_loss: 0.5472 - y2_output_loss: 1.8699 - y1_output_root_mean_squared_error: 0.7413 - y2_output_root_mean_squared_error: 1.3717 - val_loss: 2.8325 - val_y1_output_loss: 0.4945 - val_y2_output_loss: 2.3498 - val_y1_output_root_mean_squared_error: 0.6829 - val_y2_output_root_mean_squared_error: 1.5382
# Epoch 118/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.6523 - y1_output_loss: 0.6474 - y2_output_loss: 1.9823 - y1_output_root_mean_squared_error: 0.8081 - y2_output_root_mean_squared_error: 1.4140 - val_loss: 3.5416 - val_y1_output_loss: 0.6288 - val_y2_output_loss: 2.9685 - val_y1_output_root_mean_squared_error: 0.7923 - val_y2_output_root_mean_squared_error: 1.7070
# Epoch 119/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.2270 - y1_output_loss: 0.5059 - y2_output_loss: 1.7114 - y1_output_root_mean_squared_error: 0.7140 - y2_output_root_mean_squared_error: 1.3105 - val_loss: 4.8892 - val_y1_output_loss: 0.5486 - val_y2_output_loss: 4.2509 - val_y1_output_root_mean_squared_error: 0.7176 - val_y2_output_root_mean_squared_error: 2.0915
# Epoch 120/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.0201 - y1_output_loss: 0.4452 - y2_output_loss: 1.5812 - y1_output_root_mean_squared_error: 0.6662 - y2_output_root_mean_squared_error: 1.2555 - val_loss: 3.1597 - val_y1_output_loss: 0.5106 - val_y2_output_loss: 2.5974 - val_y1_output_root_mean_squared_error: 0.7021 - val_y2_output_root_mean_squared_error: 1.6330
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3876 - y1_output_loss: 0.1190 - y2_output_loss: 0.2673 - y1_output_root_mean_squared_error: 0.3456 - y2_output_root_mean_squared_error: 0.5178 - val_loss: 1.0983 - val_y1_output_loss: 0.2256 - val_y2_output_loss: 0.9026 - val_y1_output_root_mean_squared_error: 0.4572 - val_y2_output_root_mean_squared_error: 0.9430
# Epoch 462/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3576 - y1_output_loss: 0.1210 - y2_output_loss: 0.2354 - y1_output_root_mean_squared_error: 0.3488 - y2_output_root_mean_squared_error: 0.4857 - val_loss: 1.3124 - val_y1_output_loss: 0.1976 - val_y2_output_loss: 1.1001 - val_y1_output_root_mean_squared_error: 0.4365 - val_y2_output_root_mean_squared_error: 1.0592
# Epoch 463/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3948 - y1_output_loss: 0.1185 - y2_output_loss: 0.2820 - y1_output_root_mean_squared_error: 0.3428 - y2_output_root_mean_squared_error: 0.5266 - val_loss: 2.4362 - val_y1_output_loss: 0.2990 - val_y2_output_loss: 2.0951 - val_y1_output_root_mean_squared_error: 0.5316 - val_y2_output_root_mean_squared_error: 1.4675
# Epoch 464/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4144 - y1_output_loss: 0.1236 - y2_output_loss: 0.3044 - y1_output_root_mean_squared_error: 0.3450 - y2_output_root_mean_squared_error: 0.5435 - val_loss: 2.7255 - val_y1_output_loss: 0.4473 - val_y2_output_loss: 2.2123 - val_y1_output_root_mean_squared_error: 0.6674 - val_y2_output_root_mean_squared_error: 1.5100
# Epoch 465/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4426 - y1_output_loss: 0.1215 - y2_output_loss: 0.3177 - y1_output_root_mean_squared_error: 0.3498 - y2_output_root_mean_squared_error: 0.5659 - val_loss: 1.0630 - val_y1_output_loss: 0.1988 - val_y2_output_loss: 0.8554 - val_y1_output_root_mean_squared_error: 0.4382 - val_y2_output_root_mean_squared_error: 0.9332
# Epoch 466/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3487 - y1_output_loss: 0.1087 - y2_output_loss: 0.2389 - y1_output_root_mean_squared_error: 0.3304 - y2_output_root_mean_squared_error: 0.4894 - val_loss: 1.1280 - val_y1_output_loss: 0.2490 - val_y2_output_loss: 0.8926 - val_y1_output_root_mean_squared_error: 0.4876 - val_y2_output_root_mean_squared_error: 0.9435
# Epoch 467/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.5016 - y1_output_loss: 0.1630 - y2_output_loss: 0.3372 - y1_output_root_mean_squared_error: 0.4046 - y2_output_root_mean_squared_error: 0.5813 - val_loss: 1.1708 - val_y1_output_loss: 0.2354 - val_y2_output_loss: 0.9634 - val_y1_output_root_mean_squared_error: 0.4649 - val_y2_output_root_mean_squared_error: 0.9771
# Epoch 468/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3173 - y1_output_loss: 0.1111 - y2_output_loss: 0.2089 - y1_output_root_mean_squared_error: 0.3318 - y2_output_root_mean_squared_error: 0.4551 - val_loss: 1.1022 - val_y1_output_loss: 0.2354 - val_y2_output_loss: 0.8733 - val_y1_output_root_mean_squared_error: 0.4754 - val_y2_output_root_mean_squared_error: 0.9361
# Epoch 469/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5450 - y1_output_loss: 0.1374 - y2_output_loss: 0.4038 - y1_output_root_mean_squared_error: 0.3721 - y2_output_root_mean_squared_error: 0.6376 - val_loss: 1.5327 - val_y1_output_loss: 0.1997 - val_y2_output_loss: 1.3015 - val_y1_output_root_mean_squared_error: 0.4363 - val_y2_output_root_mean_squared_error: 1.1586
# Epoch 470/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3911 - y1_output_loss: 0.1194 - y2_output_loss: 0.2698 - y1_output_root_mean_squared_error: 0.3459 - y2_output_root_mean_squared_error: 0.5210 - val_loss: 1.1904 - val_y1_output_loss: 0.2824 - val_y2_output_loss: 0.9386 - val_y1_output_root_mean_squared_error: 0.5129 - val_y2_output_root_mean_squared_error: 0.9630
# Epoch 471/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3771 - y1_output_loss: 0.1261 - y2_output_loss: 0.2591 - y1_output_root_mean_squared_error: 0.3480 - y2_output_root_mean_squared_error: 0.5059 - val_loss: 2.7718 - val_y1_output_loss: 0.6771 - val_y2_output_loss: 2.0304 - val_y1_output_root_mean_squared_error: 0.8237 - val_y2_output_root_mean_squared_error: 1.4469
# Epoch 472/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.6417 - y1_output_loss: 0.1729 - y2_output_loss: 0.4649 - y1_output_root_mean_squared_error: 0.4176 - y2_output_root_mean_squared_error: 0.6836 - val_loss: 1.2243 - val_y1_output_loss: 0.2068 - val_y2_output_loss: 1.0100 - val_y1_output_root_mean_squared_error: 0.4371 - val_y2_output_root_mean_squared_error: 1.0165
# Epoch 473/500
# 614/614 [==============================] - 0s 250us/sample - loss: 0.3934 - y1_output_loss: 0.1158 - y2_output_loss: 0.2749 - y1_output_root_mean_squared_error: 0.3417 - y2_output_root_mean_squared_error: 0.5259 - val_loss: 1.1122 - val_y1_output_loss: 0.2012 - val_y2_output_loss: 0.8994 - val_y1_output_root_mean_squared_error: 0.4369 - val_y2_output_root_mean_squared_error: 0.9599
# Epoch 474/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3842 - y1_output_loss: 0.1314 - y2_output_loss: 0.2510 - y1_output_root_mean_squared_error: 0.3633 - y2_output_root_mean_squared_error: 0.5023 - val_loss: 1.2587 - val_y1_output_loss: 0.2680 - val_y2_output_loss: 1.0059 - val_y1_output_root_mean_squared_error: 0.4994 - val_y2_output_root_mean_squared_error: 1.0046
# Epoch 475/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4774 - y1_output_loss: 0.1210 - y2_output_loss: 0.3531 - y1_output_root_mean_squared_error: 0.3494 - y2_output_root_mean_squared_error: 0.5961 - val_loss: 1.1769 - val_y1_output_loss: 0.2470 - val_y2_output_loss: 0.9419 - val_y1_output_root_mean_squared_error: 0.4725 - val_y2_output_root_mean_squared_error: 0.9765
# Epoch 476/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3824 - y1_output_loss: 0.1180 - y2_output_loss: 0.2624 - y1_output_root_mean_squared_error: 0.3448 - y2_output_root_mean_squared_error: 0.5133 - val_loss: 1.1352 - val_y1_output_loss: 0.1997 - val_y2_output_loss: 0.9343 - val_y1_output_root_mean_squared_error: 0.4347 - val_y2_output_root_mean_squared_error: 0.9727
# Epoch 477/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3667 - y1_output_loss: 0.1136 - y2_output_loss: 0.2541 - y1_output_root_mean_squared_error: 0.3370 - y2_output_root_mean_squared_error: 0.5031 - val_loss: 2.0453 - val_y1_output_loss: 0.4145 - val_y2_output_loss: 1.6245 - val_y1_output_root_mean_squared_error: 0.6257 - val_y2_output_root_mean_squared_error: 1.2860
# Epoch 478/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3669 - y1_output_loss: 0.1144 - y2_output_loss: 0.2518 - y1_output_root_mean_squared_error: 0.3392 - y2_output_root_mean_squared_error: 0.5019 - val_loss: 1.3494 - val_y1_output_loss: 0.2277 - val_y2_output_loss: 1.1224 - val_y1_output_root_mean_squared_error: 0.4606 - val_y2_output_root_mean_squared_error: 1.0664
# Epoch 479/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.6397 - y1_output_loss: 0.1901 - y2_output_loss: 0.4450 - y1_output_root_mean_squared_error: 0.4374 - y2_output_root_mean_squared_error: 0.6696 - val_loss: 1.3777 - val_y1_output_loss: 0.2708 - val_y2_output_loss: 1.0960 - val_y1_output_root_mean_squared_error: 0.5068 - val_y2_output_root_mean_squared_error: 1.0587
# Epoch 480/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3897 - y1_output_loss: 0.1169 - y2_output_loss: 0.2708 - y1_output_root_mean_squared_error: 0.3425 - y2_output_root_mean_squared_error: 0.5219 - val_loss: 1.0202 - val_y1_output_loss: 0.2473 - val_y2_output_loss: 0.7827 - val_y1_output_root_mean_squared_error: 0.4853 - val_y2_output_root_mean_squared_error: 0.8858
# Epoch 481/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3065 - y1_output_loss: 0.1032 - y2_output_loss: 0.2020 - y1_output_root_mean_squared_error: 0.3214 - y2_output_root_mean_squared_error: 0.4509 - val_loss: 1.1122 - val_y1_output_loss: 0.2977 - val_y2_output_loss: 0.8243 - val_y1_output_root_mean_squared_error: 0.5379 - val_y2_output_root_mean_squared_error: 0.9071
# Epoch 482/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4064 - y1_output_loss: 0.1294 - y2_output_loss: 0.2762 - y1_output_root_mean_squared_error: 0.3596 - y2_output_root_mean_squared_error: 0.5263 - val_loss: 1.3292 - val_y1_output_loss: 0.3023 - val_y2_output_loss: 1.0290 - val_y1_output_root_mean_squared_error: 0.5377 - val_y2_output_root_mean_squared_error: 1.0198
# Epoch 483/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4131 - y1_output_loss: 0.1211 - y2_output_loss: 0.2894 - y1_output_root_mean_squared_error: 0.3489 - y2_output_root_mean_squared_error: 0.5398 - val_loss: 1.2675 - val_y1_output_loss: 0.3095 - val_y2_output_loss: 0.9783 - val_y1_output_root_mean_squared_error: 0.5313 - val_y2_output_root_mean_squared_error: 0.9926
# Epoch 484/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3697 - y1_output_loss: 0.1101 - y2_output_loss: 0.2566 - y1_output_root_mean_squared_error: 0.3331 - y2_output_root_mean_squared_error: 0.5087 - val_loss: 1.2298 - val_y1_output_loss: 0.2214 - val_y2_output_loss: 1.0172 - val_y1_output_root_mean_squared_error: 0.4488 - val_y2_output_root_mean_squared_error: 1.0141
# Epoch 485/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4535 - y1_output_loss: 0.1178 - y2_output_loss: 0.3349 - y1_output_root_mean_squared_error: 0.3439 - y2_output_root_mean_squared_error: 0.5790 - val_loss: 1.3433 - val_y1_output_loss: 0.3159 - val_y2_output_loss: 1.0356 - val_y1_output_root_mean_squared_error: 0.5417 - val_y2_output_root_mean_squared_error: 1.0247
# Epoch 486/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4220 - y1_output_loss: 0.1290 - y2_output_loss: 0.2931 - y1_output_root_mean_squared_error: 0.3587 - y2_output_root_mean_squared_error: 0.5417 - val_loss: 1.5400 - val_y1_output_loss: 0.3816 - val_y2_output_loss: 1.1533 - val_y1_output_root_mean_squared_error: 0.5966 - val_y2_output_root_mean_squared_error: 1.0881
# Epoch 487/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3358 - y1_output_loss: 0.1144 - y2_output_loss: 0.2340 - y1_output_root_mean_squared_error: 0.3392 - y2_output_root_mean_squared_error: 0.4698 - val_loss: 3.3597 - val_y1_output_loss: 0.2409 - val_y2_output_loss: 3.0377 - val_y1_output_root_mean_squared_error: 0.4811 - val_y2_output_root_mean_squared_error: 1.7687
# Epoch 488/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4211 - y1_output_loss: 0.1210 - y2_output_loss: 0.2974 - y1_output_root_mean_squared_error: 0.3492 - y2_output_root_mean_squared_error: 0.5469 - val_loss: 1.1718 - val_y1_output_loss: 0.1884 - val_y2_output_loss: 0.9753 - val_y1_output_root_mean_squared_error: 0.4232 - val_y2_output_root_mean_squared_error: 0.9964
# Epoch 489/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4102 - y1_output_loss: 0.1165 - y2_output_loss: 0.2922 - y1_output_root_mean_squared_error: 0.3402 - y2_output_root_mean_squared_error: 0.5427 - val_loss: 1.0152 - val_y1_output_loss: 0.2074 - val_y2_output_loss: 0.8080 - val_y1_output_root_mean_squared_error: 0.4419 - val_y2_output_root_mean_squared_error: 0.9055
# Epoch 490/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4822 - y1_output_loss: 0.1129 - y2_output_loss: 0.3673 - y1_output_root_mean_squared_error: 0.3373 - y2_output_root_mean_squared_error: 0.6070 - val_loss: 1.2468 - val_y1_output_loss: 0.2687 - val_y2_output_loss: 0.9770 - val_y1_output_root_mean_squared_error: 0.5099 - val_y2_output_root_mean_squared_error: 0.9934
# Epoch 491/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3802 - y1_output_loss: 0.1261 - y2_output_loss: 0.2510 - y1_output_root_mean_squared_error: 0.3568 - y2_output_root_mean_squared_error: 0.5028 - val_loss: 1.0490 - val_y1_output_loss: 0.2531 - val_y2_output_loss: 0.7941 - val_y1_output_root_mean_squared_error: 0.4959 - val_y2_output_root_mean_squared_error: 0.8962
# Epoch 492/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3113 - y1_output_loss: 0.1094 - y2_output_loss: 0.2035 - y1_output_root_mean_squared_error: 0.3287 - y2_output_root_mean_squared_error: 0.4508 - val_loss: 1.0859 - val_y1_output_loss: 0.2155 - val_y2_output_loss: 0.8722 - val_y1_output_root_mean_squared_error: 0.4580 - val_y2_output_root_mean_squared_error: 0.9360
# Epoch 493/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3555 - y1_output_loss: 0.1185 - y2_output_loss: 0.2355 - y1_output_root_mean_squared_error: 0.3448 - y2_output_root_mean_squared_error: 0.4865 - val_loss: 1.1092 - val_y1_output_loss: 0.2243 - val_y2_output_loss: 0.8860 - val_y1_output_root_mean_squared_error: 0.4655 - val_y2_output_root_mean_squared_error: 0.9448
# Epoch 494/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3043 - y1_output_loss: 0.1045 - y2_output_loss: 0.1981 - y1_output_root_mean_squared_error: 0.3238 - y2_output_root_mean_squared_error: 0.4466 - val_loss: 1.0769 - val_y1_output_loss: 0.2428 - val_y2_output_loss: 0.8638 - val_y1_output_root_mean_squared_error: 0.4758 - val_y2_output_root_mean_squared_error: 0.9222
# Epoch 495/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3378 - y1_output_loss: 0.1102 - y2_output_loss: 0.2265 - y1_output_root_mean_squared_error: 0.3321 - y2_output_root_mean_squared_error: 0.4770 - val_loss: 1.0684 - val_y1_output_loss: 0.2502 - val_y2_output_loss: 0.8429 - val_y1_output_root_mean_squared_error: 0.4828 - val_y2_output_root_mean_squared_error: 0.9140
# Epoch 496/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3730 - y1_output_loss: 0.1162 - y2_output_loss: 0.2551 - y1_output_root_mean_squared_error: 0.3421 - y2_output_root_mean_squared_error: 0.5060 - val_loss: 1.2086 - val_y1_output_loss: 0.2249 - val_y2_output_loss: 0.9868 - val_y1_output_root_mean_squared_error: 0.4601 - val_y2_output_root_mean_squared_error: 0.9984
# Epoch 497/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4203 - y1_output_loss: 0.1274 - y2_output_loss: 0.2908 - y1_output_root_mean_squared_error: 0.3573 - y2_output_root_mean_squared_error: 0.5409 - val_loss: 1.0700 - val_y1_output_loss: 0.2404 - val_y2_output_loss: 0.8510 - val_y1_output_root_mean_squared_error: 0.4759 - val_y2_output_root_mean_squared_error: 0.9184
# Epoch 498/500
# 614/614 [==============================] - 0s 164us/sample - loss: 0.4612 - y1_output_loss: 0.1274 - y2_output_loss: 0.3317 - y1_output_root_mean_squared_error: 0.3565 - y2_output_root_mean_squared_error: 0.5780 - val_loss: 1.2492 - val_y1_output_loss: 0.2936 - val_y2_output_loss: 0.9687 - val_y1_output_root_mean_squared_error: 0.5228 - val_y2_output_root_mean_squared_error: 0.9878
# Epoch 499/500
# 614/614 [==============================] - 0s 185us/sample - loss: 0.3676 - y1_output_loss: 0.1165 - y2_output_loss: 0.2490 - y1_output_root_mean_squared_error: 0.3423 - y2_output_root_mean_squared_error: 0.5005 - val_loss: 1.1781 - val_y1_output_loss: 0.2664 - val_y2_output_loss: 0.9508 - val_y1_output_root_mean_squared_error: 0.4944 - val_y2_output_root_mean_squared_error: 0.9663
# Epoch 500/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.5977 - y1_output_loss: 0.1444 - y2_output_loss: 0.4541 - y1_output_root_mean_squared_error: 0.3782 - y2_output_root_mean_squared_error: 0.6743 - val_loss: 1.1252 - val_y1_output_loss: 0.2652 - val_y2_output_loss: 0.8903 - val_y1_output_root_mean_squared_error: 0.4956 - val_y2_output_root_mean_squared_error: 0.9378

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss: np.ndarray;
Y1_loss: np.ndarray;
Y2_loss: np.ndarray;
Y1_rmse: np.ndarray;
Y2_rmse: np.ndarray;
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(
    x=norm_test_X, y=test_Y
);
print(f"Loss = {loss}, Y1_loss = {Y1_loss}, Y1_mse = {Y1_rmse}, Y2_loss = \
{Y2_loss}, Y2_mse = {Y2_rmse}");
# Out:
# 154/154 [==============================] - 0s 36us/sample - loss: 1.1252 - y1_output_loss: 0.2449 - y2_output_loss: 0.8788 - y1_output_root_mean_squared_error: 0.4956 - y2_output_root_mean_squared_error: 0.9378
# Loss = 1.125150912767881, Y1_loss = 0.24491949379444122, Y1_mse = 0.49564090371131897, Y2_loss = 0.8787714838981628, Y2_mse = 0.9378118515014648

# %%
# Plot the loss and mse
Y_pred: np.ndarray = model.predict(norm_test_X);
plot_diff(test_Y[0], Y_pred[0], title='Y1');
plot_diff(test_Y[1], Y_pred[1], title='Y2');
plot_metrics(
    metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6
);
plot_metrics(
    metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7
);
