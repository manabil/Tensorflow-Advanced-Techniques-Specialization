# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data: pd.DataFrame) -> tuple:
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x: pd.DataFrame) -> pd.DataFrame:
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true: np.ndarray, y_pred: np.ndarray, title: str='') -> None:
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name: str, title: str, ylim: int=5) -> None:
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(
        history.history[f'val_{metric_name}'],
        color='green',
        label=f'val_{metric_name}'
    )
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI: str = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df: pd.DataFrame = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train: pd.DataFrame
test: pd.DataFrame
train, test = train_test_split(df, test_size=0.2)
train_stats: pd.DataFrame = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y: tuple = format_output(train)
test_Y: tuple = format_output(test)

# Normalize the training and test data
norm_train_X: pd.DataFrame = norm(train)
norm_test_X: pd.DataFrame = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer: tf.keras.layers.Layer = Input(shape=(len(train.columns),))
first_dense: tf.keras.layers.Layer = Dense(
    units='128', activation='relu'
)(input_layer)
second_dense: tf.keras.layers.Layer = Dense(
    units='128', activation='relu'
)(first_dense)

# Y1 output will be fed directly from the second dense
y1_output: tf.keras.layers.Layer = Dense(
    units='1', name='y1_output'
)(second_dense)
third_dense: tf.keras.layers.Layer = Dense(
    units='64', activation='relu'
)(second_dense)

# Y2 output will come via the third dense
y2_output: tf.keras.layers.Layer = Dense(
    units='1', name='y2_output'
)(third_dense)

# Define the model with the input layer and a list of output layers
model: Model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          1152        input_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          16512       dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           8256        dense_4[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_4[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_5[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both 
# outputs
optimizer: tf.keras.optimizers.Optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(
    optimizer=optimizer,
    loss={'y1_output': 'mse', 'y2_output': 'mse'},
    metrics={
        'y1_output': tf.keras.metrics.RootMeanSquaredError(),
        'y2_output': tf.keras.metrics.RootMeanSquaredError()
    }
)

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history: tf.keras.callbacks.History = model.fit(
    norm_train_X,
    train_Y,
    epochs=500,
    batch_size=10,
    validation_data=(norm_test_X, test_Y)
)
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 951us/sample - loss: 233.3475 - y1_output_loss: 107.7623 - y2_output_loss: 123.5055 - y1_output_root_mean_squared_error: 10.4285 - y2_output_root_mean_squared_error: 11.1622 - val_loss: 59.6793 - val_y1_output_loss: 17.9921 - val_y2_output_loss: 40.8306 - val_y1_output_root_mean_squared_error: 4.2809 - val_y2_output_root_mean_squared_error: 6.4307
# Epoch 2/500
# 614/614 [==============================] - 0s 169us/sample - loss: 32.6348 - y1_output_loss: 12.1386 - y2_output_loss: 20.7793 - y1_output_root_mean_squared_error: 3.4806 - y2_output_root_mean_squared_error: 4.5299 - val_loss: 26.5006 - val_y1_output_loss: 11.9566 - val_y2_output_loss: 13.7857 - val_y1_output_root_mean_squared_error: 3.5153 - val_y2_output_root_mean_squared_error: 3.7607
# Epoch 3/500
# 614/614 [==============================] - 0s 167us/sample - loss: 25.1369 - y1_output_loss: 9.3519 - y2_output_loss: 15.5475 - y1_output_root_mean_squared_error: 3.0725 - y2_output_root_mean_squared_error: 3.9619 - val_loss: 21.5050 - val_y1_output_loss: 10.1983 - val_y2_output_loss: 10.6642 - val_y1_output_root_mean_squared_error: 3.2363 - val_y2_output_root_mean_squared_error: 3.3214
# Epoch 4/500
# 614/614 [==============================] - 0s 156us/sample - loss: 24.8443 - y1_output_loss: 9.2916 - y2_output_loss: 15.9413 - y1_output_root_mean_squared_error: 3.0407 - y2_output_root_mean_squared_error: 3.9495 - val_loss: 53.6560 - val_y1_output_loss: 14.7445 - val_y2_output_loss: 38.2947 - val_y1_output_root_mean_squared_error: 3.8925 - val_y2_output_root_mean_squared_error: 6.2052
# Epoch 5/500
# 614/614 [==============================] - 0s 155us/sample - loss: 26.0988 - y1_output_loss: 9.8677 - y2_output_loss: 16.0820 - y1_output_root_mean_squared_error: 3.1420 - y2_output_root_mean_squared_error: 4.0282 - val_loss: 55.8708 - val_y1_output_loss: 17.8080 - val_y2_output_loss: 38.3777 - val_y1_output_root_mean_squared_error: 4.1946 - val_y2_output_root_mean_squared_error: 6.1868
# Epoch 6/500
# 614/614 [==============================] - 0s 153us/sample - loss: 27.9527 - y1_output_loss: 9.4451 - y2_output_loss: 18.2800 - y1_output_root_mean_squared_error: 3.0868 - y2_output_root_mean_squared_error: 4.2923 - val_loss: 24.2392 - val_y1_output_loss: 10.7229 - val_y2_output_loss: 12.8154 - val_y1_output_root_mean_squared_error: 3.3360 - val_y2_output_root_mean_squared_error: 3.6208
# Epoch 7/500
# 614/614 [==============================] - 0s 152us/sample - loss: 22.1345 - y1_output_loss: 8.2465 - y2_output_loss: 13.7204 - y1_output_root_mean_squared_error: 2.8831 - y2_output_root_mean_squared_error: 3.7178 - val_loss: 20.3479 - val_y1_output_loss: 9.4583 - val_y2_output_loss: 10.3134 - val_y1_output_root_mean_squared_error: 3.1199 - val_y2_output_root_mean_squared_error: 3.2580
# Epoch 8/500
# 614/614 [==============================] - 0s 158us/sample - loss: 23.3636 - y1_output_loss: 8.5445 - y2_output_loss: 14.7344 - y1_output_root_mean_squared_error: 2.9224 - y2_output_root_mean_squared_error: 3.8501 - val_loss: 39.5650 - val_y1_output_loss: 12.0073 - val_y2_output_loss: 27.4077 - val_y1_output_root_mean_squared_error: 3.4672 - val_y2_output_root_mean_squared_error: 5.2482
# Epoch 9/500
# 614/614 [==============================] - 0s 151us/sample - loss: 21.1573 - y1_output_loss: 8.1312 - y2_output_loss: 12.8519 - y1_output_root_mean_squared_error: 2.8619 - y2_output_root_mean_squared_error: 3.6009 - val_loss: 20.8358 - val_y1_output_loss: 9.3122 - val_y2_output_loss: 10.9431 - val_y1_output_root_mean_squared_error: 3.0959 - val_y2_output_root_mean_squared_error: 3.3543
# Epoch 10/500
# 614/614 [==============================] - 0s 152us/sample - loss: 18.9893 - y1_output_loss: 7.4282 - y2_output_loss: 11.6581 - y1_output_root_mean_squared_error: 2.7160 - y2_output_root_mean_squared_error: 3.4077 - val_loss: 25.3679 - val_y1_output_loss: 12.1970 - val_y2_output_loss: 13.2357 - val_y1_output_root_mean_squared_error: 3.4768 - val_y2_output_root_mean_squared_error: 3.6442
# Epoch 11/500
# 614/614 [==============================] - 0s 164us/sample - loss: 20.4137 - y1_output_loss: 7.5906 - y2_output_loss: 12.6809 - y1_output_root_mean_squared_error: 2.7653 - y2_output_root_mean_squared_error: 3.5730 - val_loss: 18.7307 - val_y1_output_loss: 9.1793 - val_y2_output_loss: 9.1407 - val_y1_output_root_mean_squared_error: 3.0549 - val_y2_output_root_mean_squared_error: 3.0656
# Epoch 12/500
# 614/614 [==============================] - 0s 159us/sample - loss: 21.4531 - y1_output_loss: 7.8950 - y2_output_loss: 13.4217 - y1_output_root_mean_squared_error: 2.8182 - y2_output_root_mean_squared_error: 3.6757 - val_loss: 19.7397 - val_y1_output_loss: 9.2532 - val_y2_output_loss: 10.0543 - val_y1_output_root_mean_squared_error: 3.0685 - val_y2_output_root_mean_squared_error: 3.2131
# Epoch 13/500
# 614/614 [==============================] - 0s 156us/sample - loss: 18.0017 - y1_output_loss: 7.0476 - y2_output_loss: 10.9023 - y1_output_root_mean_squared_error: 2.6508 - y2_output_root_mean_squared_error: 3.3129 - val_loss: 18.6546 - val_y1_output_loss: 9.5689 - val_y2_output_loss: 8.5422 - val_y1_output_root_mean_squared_error: 3.1411 - val_y2_output_root_mean_squared_error: 2.9645
# Epoch 14/500
# 614/614 [==============================] - 0s 153us/sample - loss: 19.1835 - y1_output_loss: 7.2155 - y2_output_loss: 11.8046 - y1_output_root_mean_squared_error: 2.6987 - y2_output_root_mean_squared_error: 3.4497 - val_loss: 16.8086 - val_y1_output_loss: 7.9156 - val_y2_output_loss: 8.5414 - val_y1_output_root_mean_squared_error: 2.8416 - val_y2_output_root_mean_squared_error: 2.9553
# Epoch 15/500
# 614/614 [==============================] - 0s 154us/sample - loss: 16.8673 - y1_output_loss: 6.7743 - y2_output_loss: 10.2622 - y1_output_root_mean_squared_error: 2.5883 - y2_output_root_mean_squared_error: 3.1887 - val_loss: 26.2935 - val_y1_output_loss: 11.5768 - val_y2_output_loss: 14.7252 - val_y1_output_root_mean_squared_error: 3.3816 - val_y2_output_root_mean_squared_error: 3.8547
# Epoch 16/500
# 614/614 [==============================] - 0s 150us/sample - loss: 15.2463 - y1_output_loss: 6.0509 - y2_output_loss: 9.1231 - y1_output_root_mean_squared_error: 2.4691 - y2_output_root_mean_squared_error: 3.0249 - val_loss: 19.4850 - val_y1_output_loss: 8.0721 - val_y2_output_loss: 10.9082 - val_y1_output_root_mean_squared_error: 2.8915 - val_y2_output_root_mean_squared_error: 3.3353
# Epoch 17/500
# 614/614 [==============================] - 0s 144us/sample - loss: 14.8780 - y1_output_loss: 5.7672 - y2_output_loss: 8.9897 - y1_output_root_mean_squared_error: 2.4113 - y2_output_root_mean_squared_error: 3.0106 - val_loss: 16.4947 - val_y1_output_loss: 7.1320 - val_y2_output_loss: 8.8553 - val_y1_output_root_mean_squared_error: 2.7089 - val_y2_output_root_mean_squared_error: 3.0260
# Epoch 18/500
# 614/614 [==============================] - 0s 142us/sample - loss: 15.6787 - y1_output_loss: 6.0504 - y2_output_loss: 9.5585 - y1_output_root_mean_squared_error: 2.4566 - y2_output_root_mean_squared_error: 3.1054 - val_loss: 20.9423 - val_y1_output_loss: 8.5250 - val_y2_output_loss: 12.0779 - val_y1_output_root_mean_squared_error: 2.9370 - val_y2_output_root_mean_squared_error: 3.5095
# Epoch 19/500
# 614/614 [==============================] - 0s 144us/sample - loss: 15.2558 - y1_output_loss: 5.2772 - y2_output_loss: 9.8786 - y1_output_root_mean_squared_error: 2.3058 - y2_output_root_mean_squared_error: 3.1526 - val_loss: 15.9814 - val_y1_output_loss: 6.9115 - val_y2_output_loss: 8.6463 - val_y1_output_root_mean_squared_error: 2.6648 - val_y2_output_root_mean_squared_error: 2.9799
# Epoch 20/500
# 614/614 [==============================] - 0s 147us/sample - loss: 15.3761 - y1_output_loss: 5.7152 - y2_output_loss: 9.6303 - y1_output_root_mean_squared_error: 2.3872 - y2_output_root_mean_squared_error: 3.1109 - val_loss: 21.0723 - val_y1_output_loss: 8.8562 - val_y2_output_loss: 11.7683 - val_y1_output_root_mean_squared_error: 3.0267 - val_y2_output_root_mean_squared_error: 3.4513
# Epoch 21/500
# 614/614 [==============================] - 0s 156us/sample - loss: 15.3071 - y1_output_loss: 5.3475 - y2_output_loss: 9.8410 - y1_output_root_mean_squared_error: 2.3223 - y2_output_root_mean_squared_error: 3.1487 - val_loss: 13.3604 - val_y1_output_loss: 6.0999 - val_y2_output_loss: 6.8746 - val_y1_output_root_mean_squared_error: 2.4956 - val_y2_output_root_mean_squared_error: 2.6707
# Epoch 22/500
# 614/614 [==============================] - 0s 155us/sample - loss: 13.8054 - y1_output_loss: 5.1687 - y2_output_loss: 8.6087 - y1_output_root_mean_squared_error: 2.2659 - y2_output_root_mean_squared_error: 2.9447 - val_loss: 17.7396 - val_y1_output_loss: 6.9943 - val_y2_output_loss: 10.3426 - val_y1_output_root_mean_squared_error: 2.6929 - val_y2_output_root_mean_squared_error: 3.2385
# Epoch 23/500
# 614/614 [==============================] - 0s 150us/sample - loss: 11.5773 - y1_output_loss: 4.4009 - y2_output_loss: 7.1723 - y1_output_root_mean_squared_error: 2.1044 - y2_output_root_mean_squared_error: 2.6737 - val_loss: 22.9801 - val_y1_output_loss: 7.6407 - val_y2_output_loss: 14.8505 - val_y1_output_root_mean_squared_error: 2.8164 - val_y2_output_root_mean_squared_error: 3.8792
# Epoch 24/500
# 614/614 [==============================] - 0s 152us/sample - loss: 13.8677 - y1_output_loss: 4.8010 - y2_output_loss: 9.0506 - y1_output_root_mean_squared_error: 2.1858 - y2_output_root_mean_squared_error: 3.0149 - val_loss: 17.3049 - val_y1_output_loss: 6.6275 - val_y2_output_loss: 10.3996 - val_y1_output_root_mean_squared_error: 2.5856 - val_y2_output_root_mean_squared_error: 3.2587
# Epoch 25/500
# 614/614 [==============================] - 0s 154us/sample - loss: 12.1912 - y1_output_loss: 4.4552 - y2_output_loss: 7.6706 - y1_output_root_mean_squared_error: 2.1201 - y2_output_root_mean_squared_error: 2.7742 - val_loss: 16.7578 - val_y1_output_loss: 5.9766 - val_y2_output_loss: 10.4219 - val_y1_output_root_mean_squared_error: 2.4858 - val_y2_output_root_mean_squared_error: 3.2525
# Epoch 26/500
# 614/614 [==============================] - 0s 150us/sample - loss: 10.9895 - y1_output_loss: 4.0405 - y2_output_loss: 6.9211 - y1_output_root_mean_squared_error: 2.0145 - y2_output_root_mean_squared_error: 2.6327 - val_loss: 13.7327 - val_y1_output_loss: 5.7419 - val_y2_output_loss: 7.6388 - val_y1_output_root_mean_squared_error: 2.4270 - val_y2_output_root_mean_squared_error: 2.8004
# Epoch 27/500
# 614/614 [==============================] - 0s 152us/sample - loss: 11.9138 - y1_output_loss: 4.2990 - y2_output_loss: 7.5663 - y1_output_root_mean_squared_error: 2.0702 - y2_output_root_mean_squared_error: 2.7619 - val_loss: 12.7675 - val_y1_output_loss: 5.5495 - val_y2_output_loss: 6.8317 - val_y1_output_root_mean_squared_error: 2.3928 - val_y2_output_root_mean_squared_error: 2.6537
# Epoch 28/500
# 614/614 [==============================] - 0s 147us/sample - loss: 11.4968 - y1_output_loss: 4.1820 - y2_output_loss: 7.3597 - y1_output_root_mean_squared_error: 2.0366 - y2_output_root_mean_squared_error: 2.7109 - val_loss: 17.5888 - val_y1_output_loss: 7.5078 - val_y2_output_loss: 9.9280 - val_y1_output_root_mean_squared_error: 2.7361 - val_y2_output_root_mean_squared_error: 3.1785
# Epoch 29/500
# 614/614 [==============================] - 0s 157us/sample - loss: 10.0843 - y1_output_loss: 3.6980 - y2_output_loss: 6.3090 - y1_output_root_mean_squared_error: 1.9319 - y2_output_root_mean_squared_error: 2.5203 - val_loss: 12.5106 - val_y1_output_loss: 4.9740 - val_y2_output_loss: 7.2271 - val_y1_output_root_mean_squared_error: 2.2561 - val_y2_output_root_mean_squared_error: 2.7241
# Epoch 30/500
# 614/614 [==============================] - 0s 155us/sample - loss: 9.2326 - y1_output_loss: 3.4672 - y2_output_loss: 5.8221 - y1_output_root_mean_squared_error: 1.8503 - y2_output_root_mean_squared_error: 2.4101 - val_loss: 10.1723 - val_y1_output_loss: 4.3154 - val_y2_output_loss: 5.5687 - val_y1_output_root_mean_squared_error: 2.1015 - val_y2_output_root_mean_squared_error: 2.3991
# Epoch 31/500
# 614/614 [==============================] - 0s 153us/sample - loss: 9.4379 - y1_output_loss: 3.4707 - y2_output_loss: 6.0965 - y1_output_root_mean_squared_error: 1.8475 - y2_output_root_mean_squared_error: 2.4545 - val_loss: 17.3900 - val_y1_output_loss: 6.5982 - val_y2_output_loss: 10.4582 - val_y1_output_root_mean_squared_error: 2.6087 - val_y2_output_root_mean_squared_error: 3.2534
# Epoch 32/500
# 614/614 [==============================] - 0s 159us/sample - loss: 8.6297 - y1_output_loss: 3.1501 - y2_output_loss: 5.4663 - y1_output_root_mean_squared_error: 1.7739 - y2_output_root_mean_squared_error: 2.3415 - val_loss: 14.5170 - val_y1_output_loss: 4.4050 - val_y2_output_loss: 9.8231 - val_y1_output_root_mean_squared_error: 2.1326 - val_y2_output_root_mean_squared_error: 3.1574
# Epoch 33/500
# 614/614 [==============================] - 0s 149us/sample - loss: 9.6003 - y1_output_loss: 3.3191 - y2_output_loss: 6.4989 - y1_output_root_mean_squared_error: 1.8191 - y2_output_root_mean_squared_error: 2.5082 - val_loss: 53.9588 - val_y1_output_loss: 11.3041 - val_y2_output_loss: 43.0554 - val_y1_output_root_mean_squared_error: 3.3817 - val_y2_output_root_mean_squared_error: 6.5210
# Epoch 34/500
# 614/614 [==============================] - 0s 153us/sample - loss: 13.9678 - y1_output_loss: 4.3457 - y2_output_loss: 9.5809 - y1_output_root_mean_squared_error: 2.0759 - y2_output_root_mean_squared_error: 3.1078 - val_loss: 9.1491 - val_y1_output_loss: 3.8082 - val_y2_output_loss: 5.1115 - val_y1_output_root_mean_squared_error: 1.9711 - val_y2_output_root_mean_squared_error: 2.2943
# Epoch 35/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.5381 - y1_output_loss: 2.9475 - y2_output_loss: 5.5868 - y1_output_root_mean_squared_error: 1.7237 - y2_output_root_mean_squared_error: 2.3595 - val_loss: 11.3656 - val_y1_output_loss: 4.4742 - val_y2_output_loss: 6.5739 - val_y1_output_root_mean_squared_error: 2.1432 - val_y2_output_root_mean_squared_error: 2.6024
# Epoch 36/500
# 614/614 [==============================] - 0s 151us/sample - loss: 11.2338 - y1_output_loss: 3.6061 - y2_output_loss: 7.9217 - y1_output_root_mean_squared_error: 1.8860 - y2_output_root_mean_squared_error: 2.7707 - val_loss: 50.4600 - val_y1_output_loss: 13.6677 - val_y2_output_loss: 37.2699 - val_y1_output_root_mean_squared_error: 3.6471 - val_y2_output_root_mean_squared_error: 6.0958
# Epoch 37/500
# 614/614 [==============================] - 0s 150us/sample - loss: 8.9261 - y1_output_loss: 3.0027 - y2_output_loss: 5.9536 - y1_output_root_mean_squared_error: 1.7405 - y2_output_root_mean_squared_error: 2.4283 - val_loss: 39.0552 - val_y1_output_loss: 7.6337 - val_y2_output_loss: 31.1323 - val_y1_output_root_mean_squared_error: 2.8065 - val_y2_output_root_mean_squared_error: 5.5838
# Epoch 38/500
# 614/614 [==============================] - 0s 149us/sample - loss: 9.2209 - y1_output_loss: 2.7169 - y2_output_loss: 6.4446 - y1_output_root_mean_squared_error: 1.6510 - y2_output_root_mean_squared_error: 2.5485 - val_loss: 13.3240 - val_y1_output_loss: 5.0212 - val_y2_output_loss: 8.0331 - val_y1_output_root_mean_squared_error: 2.2687 - val_y2_output_root_mean_squared_error: 2.8595
# Epoch 39/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.8721 - y1_output_loss: 2.3409 - y2_output_loss: 4.4688 - y1_output_root_mean_squared_error: 1.5370 - y2_output_root_mean_squared_error: 2.1236 - val_loss: 8.5276 - val_y1_output_loss: 3.2018 - val_y2_output_loss: 5.0777 - val_y1_output_root_mean_squared_error: 1.8100 - val_y2_output_root_mean_squared_error: 2.2916
# Epoch 40/500
# 614/614 [==============================] - 0s 145us/sample - loss: 8.9008 - y1_output_loss: 2.9104 - y2_output_loss: 5.9113 - y1_output_root_mean_squared_error: 1.7138 - y2_output_root_mean_squared_error: 2.4421 - val_loss: 9.2673 - val_y1_output_loss: 3.3575 - val_y2_output_loss: 5.6857 - val_y1_output_root_mean_squared_error: 1.8549 - val_y2_output_root_mean_squared_error: 2.4139
# Epoch 41/500
# 614/614 [==============================] - 0s 150us/sample - loss: 10.0055 - y1_output_loss: 2.7533 - y2_output_loss: 7.1652 - y1_output_root_mean_squared_error: 1.6663 - y2_output_root_mean_squared_error: 2.6887 - val_loss: 10.9452 - val_y1_output_loss: 3.9973 - val_y2_output_loss: 6.7468 - val_y1_output_root_mean_squared_error: 2.0200 - val_y2_output_root_mean_squared_error: 2.6201
# Epoch 42/500
# 614/614 [==============================] - 0s 149us/sample - loss: 6.6041 - y1_output_loss: 2.1542 - y2_output_loss: 4.4117 - y1_output_root_mean_squared_error: 1.4719 - y2_output_root_mean_squared_error: 2.1066 - val_loss: 8.8195 - val_y1_output_loss: 2.7294 - val_y2_output_loss: 5.8948 - val_y1_output_root_mean_squared_error: 1.6753 - val_y2_output_root_mean_squared_error: 2.4521
# Epoch 43/500
# 614/614 [==============================] - 0s 149us/sample - loss: 8.9100 - y1_output_loss: 2.6230 - y2_output_loss: 6.4470 - y1_output_root_mean_squared_error: 1.6052 - y2_output_root_mean_squared_error: 2.5166 - val_loss: 88.6514 - val_y1_output_loss: 21.1564 - val_y2_output_loss: 66.5177 - val_y1_output_root_mean_squared_error: 4.6601 - val_y2_output_root_mean_squared_error: 8.1814
# Epoch 44/500
# 614/614 [==============================] - 0s 146us/sample - loss: 14.8532 - y1_output_loss: 5.0467 - y2_output_loss: 9.7736 - y1_output_root_mean_squared_error: 2.2536 - y2_output_root_mean_squared_error: 3.1264 - val_loss: 23.5936 - val_y1_output_loss: 6.8756 - val_y2_output_loss: 17.0236 - val_y1_output_root_mean_squared_error: 2.5727 - val_y2_output_root_mean_squared_error: 4.1201
# Epoch 45/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.5071 - y1_output_loss: 2.0493 - y2_output_loss: 4.4749 - y1_output_root_mean_squared_error: 1.4240 - y2_output_root_mean_squared_error: 2.1164 - val_loss: 7.1589 - val_y1_output_loss: 2.3581 - val_y2_output_loss: 4.6667 - val_y1_output_root_mean_squared_error: 1.5306 - val_y2_output_root_mean_squared_error: 2.1946
# Epoch 46/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.2542 - y1_output_loss: 2.1373 - y2_output_loss: 5.2565 - y1_output_root_mean_squared_error: 1.4653 - y2_output_root_mean_squared_error: 2.2599 - val_loss: 10.0090 - val_y1_output_loss: 3.3747 - val_y2_output_loss: 6.3817 - val_y1_output_root_mean_squared_error: 1.8646 - val_y2_output_root_mean_squared_error: 2.5558
# Epoch 47/500
# 614/614 [==============================] - 0s 149us/sample - loss: 8.6752 - y1_output_loss: 2.6742 - y2_output_loss: 5.9797 - y1_output_root_mean_squared_error: 1.6337 - y2_output_root_mean_squared_error: 2.4508 - val_loss: 9.0712 - val_y1_output_loss: 3.0940 - val_y2_output_loss: 5.7408 - val_y1_output_root_mean_squared_error: 1.7724 - val_y2_output_root_mean_squared_error: 2.4351
# Epoch 48/500
# 614/614 [==============================] - 0s 175us/sample - loss: 5.7309 - y1_output_loss: 1.7640 - y2_output_loss: 3.9623 - y1_output_root_mean_squared_error: 1.3205 - y2_output_root_mean_squared_error: 1.9968 - val_loss: 6.5958 - val_y1_output_loss: 2.5435 - val_y2_output_loss: 3.8759 - val_y1_output_root_mean_squared_error: 1.6077 - val_y2_output_root_mean_squared_error: 2.0028
# Epoch 49/500
# 614/614 [==============================] - 0s 148us/sample - loss: 5.9852 - y1_output_loss: 1.7099 - y2_output_loss: 4.2544 - y1_output_root_mean_squared_error: 1.3064 - y2_output_root_mean_squared_error: 2.0684 - val_loss: 6.4423 - val_y1_output_loss: 2.3463 - val_y2_output_loss: 3.8861 - val_y1_output_root_mean_squared_error: 1.5516 - val_y2_output_root_mean_squared_error: 2.0087
# Epoch 50/500
# 614/614 [==============================] - 0s 157us/sample - loss: 6.1040 - y1_output_loss: 1.9104 - y2_output_loss: 4.2568 - y1_output_root_mean_squared_error: 1.3716 - y2_output_root_mean_squared_error: 2.0549 - val_loss: 27.3375 - val_y1_output_loss: 8.2636 - val_y2_output_loss: 19.3462 - val_y1_output_root_mean_squared_error: 2.8265 - val_y2_output_root_mean_squared_error: 4.3987
# Epoch 51/500
# 614/614 [==============================] - 0s 151us/sample - loss: 6.8030 - y1_output_loss: 1.9442 - y2_output_loss: 4.8047 - y1_output_root_mean_squared_error: 1.3997 - y2_output_root_mean_squared_error: 2.2009 - val_loss: 7.7244 - val_y1_output_loss: 2.4770 - val_y2_output_loss: 5.0577 - val_y1_output_root_mean_squared_error: 1.5951 - val_y2_output_root_mean_squared_error: 2.2760
# Epoch 52/500
# 614/614 [==============================] - 0s 158us/sample - loss: 5.7709 - y1_output_loss: 1.7770 - y2_output_loss: 4.0142 - y1_output_root_mean_squared_error: 1.3340 - y2_output_root_mean_squared_error: 1.9978 - val_loss: 6.9352 - val_y1_output_loss: 2.3751 - val_y2_output_loss: 4.4495 - val_y1_output_root_mean_squared_error: 1.5478 - val_y2_output_root_mean_squared_error: 2.1306
# Epoch 53/500
# 614/614 [==============================] - 0s 154us/sample - loss: 5.7490 - y1_output_loss: 1.7321 - y2_output_loss: 4.0233 - y1_output_root_mean_squared_error: 1.3076 - y2_output_root_mean_squared_error: 2.0098 - val_loss: 6.4028 - val_y1_output_loss: 2.0359 - val_y2_output_loss: 4.3063 - val_y1_output_root_mean_squared_error: 1.4050 - val_y2_output_root_mean_squared_error: 2.1045
# Epoch 54/500
# 614/614 [==============================] - 0s 164us/sample - loss: 4.8860 - y1_output_loss: 1.4150 - y2_output_loss: 3.4325 - y1_output_root_mean_squared_error: 1.1947 - y2_output_root_mean_squared_error: 1.8598 - val_loss: 7.1634 - val_y1_output_loss: 2.1883 - val_y2_output_loss: 4.8317 - val_y1_output_root_mean_squared_error: 1.4947 - val_y2_output_root_mean_squared_error: 2.2202
# Epoch 55/500
# 614/614 [==============================] - 0s 154us/sample - loss: 5.5678 - y1_output_loss: 1.6580 - y2_output_loss: 3.9257 - y1_output_root_mean_squared_error: 1.2902 - y2_output_root_mean_squared_error: 1.9756 - val_loss: 5.5289 - val_y1_output_loss: 1.8328 - val_y2_output_loss: 3.5703 - val_y1_output_root_mean_squared_error: 1.3543 - val_y2_output_root_mean_squared_error: 1.9221
# Epoch 56/500
# 614/614 [==============================] - 0s 152us/sample - loss: 5.0297 - y1_output_loss: 1.5972 - y2_output_loss: 3.4272 - y1_output_root_mean_squared_error: 1.2644 - y2_output_root_mean_squared_error: 1.8523 - val_loss: 8.5259 - val_y1_output_loss: 3.2606 - val_y2_output_loss: 5.0011 - val_y1_output_root_mean_squared_error: 1.8256 - val_y2_output_root_mean_squared_error: 2.2788
# Epoch 57/500
# 614/614 [==============================] - 0s 150us/sample - loss: 4.8242 - y1_output_loss: 1.3792 - y2_output_loss: 3.4584 - y1_output_root_mean_squared_error: 1.1734 - y2_output_root_mean_squared_error: 1.8567 - val_loss: 7.6351 - val_y1_output_loss: 1.7563 - val_y2_output_loss: 5.8150 - val_y1_output_root_mean_squared_error: 1.3064 - val_y2_output_root_mean_squared_error: 2.4348
# Epoch 58/500
# 614/614 [==============================] - 0s 148us/sample - loss: 5.1327 - y1_output_loss: 1.4240 - y2_output_loss: 3.6847 - y1_output_root_mean_squared_error: 1.1981 - y2_output_root_mean_squared_error: 1.9228 - val_loss: 4.8243 - val_y1_output_loss: 1.4987 - val_y2_output_loss: 3.2740 - val_y1_output_root_mean_squared_error: 1.1968 - val_y2_output_root_mean_squared_error: 1.8417
# Epoch 59/500
# 614/614 [==============================] - 0s 151us/sample - loss: 4.2735 - y1_output_loss: 1.2634 - y2_output_loss: 2.9923 - y1_output_root_mean_squared_error: 1.1228 - y2_output_root_mean_squared_error: 1.7358 - val_loss: 4.5621 - val_y1_output_loss: 1.4294 - val_y2_output_loss: 3.0622 - val_y1_output_root_mean_squared_error: 1.1805 - val_y2_output_root_mean_squared_error: 1.7800
# Epoch 60/500
# 614/614 [==============================] - 0s 152us/sample - loss: 9.4936 - y1_output_loss: 3.0018 - y2_output_loss: 6.7113 - y1_output_root_mean_squared_error: 1.6940 - y2_output_root_mean_squared_error: 2.5737 - val_loss: 13.0137 - val_y1_output_loss: 5.5456 - val_y2_output_loss: 7.1929 - val_y1_output_root_mean_squared_error: 2.3808 - val_y2_output_root_mean_squared_error: 2.7102
# Epoch 61/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.3080 - y1_output_loss: 1.7673 - y2_output_loss: 4.5131 - y1_output_root_mean_squared_error: 1.3303 - y2_output_root_mean_squared_error: 2.1303 - val_loss: 9.9371 - val_y1_output_loss: 2.6398 - val_y2_output_loss: 7.2209 - val_y1_output_root_mean_squared_error: 1.6134 - val_y2_output_root_mean_squared_error: 2.7082
# Epoch 62/500
# 614/614 [==============================] - 0s 152us/sample - loss: 4.1056 - y1_output_loss: 1.1284 - y2_output_loss: 2.9514 - y1_output_root_mean_squared_error: 1.0654 - y2_output_root_mean_squared_error: 1.7235 - val_loss: 4.3666 - val_y1_output_loss: 1.3126 - val_y2_output_loss: 3.0137 - val_y1_output_root_mean_squared_error: 1.1240 - val_y2_output_root_mean_squared_error: 1.7616
# Epoch 63/500
# 614/614 [==============================] - 0s 149us/sample - loss: 5.8211 - y1_output_loss: 1.5533 - y2_output_loss: 4.2549 - y1_output_root_mean_squared_error: 1.2483 - y2_output_root_mean_squared_error: 2.0647 - val_loss: 8.9049 - val_y1_output_loss: 2.4607 - val_y2_output_loss: 6.2904 - val_y1_output_root_mean_squared_error: 1.5680 - val_y2_output_root_mean_squared_error: 2.5389
# Epoch 64/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.2437 - y1_output_loss: 1.4036 - y2_output_loss: 3.8339 - y1_output_root_mean_squared_error: 1.1822 - y2_output_root_mean_squared_error: 1.9611 - val_loss: 6.7254 - val_y1_output_loss: 1.6172 - val_y2_output_loss: 5.0247 - val_y1_output_root_mean_squared_error: 1.2595 - val_y2_output_root_mean_squared_error: 2.2670
# Epoch 65/500
# 614/614 [==============================] - 0s 155us/sample - loss: 3.4541 - y1_output_loss: 0.9626 - y2_output_loss: 2.4939 - y1_output_root_mean_squared_error: 0.9850 - y2_output_root_mean_squared_error: 1.5760 - val_loss: 7.5213 - val_y1_output_loss: 1.1725 - val_y2_output_loss: 6.2278 - val_y1_output_root_mean_squared_error: 1.0859 - val_y2_output_root_mean_squared_error: 2.5184
# Epoch 66/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.7677 - y1_output_loss: 1.0916 - y2_output_loss: 2.7335 - y1_output_root_mean_squared_error: 1.0393 - y2_output_root_mean_squared_error: 1.6393 - val_loss: 9.7901 - val_y1_output_loss: 1.8260 - val_y2_output_loss: 7.9409 - val_y1_output_root_mean_squared_error: 1.3383 - val_y2_output_root_mean_squared_error: 2.8283
# Epoch 67/500
# 614/614 [==============================] - 0s 152us/sample - loss: 4.4934 - y1_output_loss: 1.2498 - y2_output_loss: 3.2139 - y1_output_root_mean_squared_error: 1.1227 - y2_output_root_mean_squared_error: 1.7981 - val_loss: 4.3373 - val_y1_output_loss: 1.3439 - val_y2_output_loss: 2.9216 - val_y1_output_root_mean_squared_error: 1.1511 - val_y2_output_root_mean_squared_error: 1.7356
# Epoch 68/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.9116 - y1_output_loss: 1.0591 - y2_output_loss: 2.8276 - y1_output_root_mean_squared_error: 1.0301 - y2_output_root_mean_squared_error: 1.6884 - val_loss: 3.8667 - val_y1_output_loss: 0.9525 - val_y2_output_loss: 2.8641 - val_y1_output_root_mean_squared_error: 0.9624 - val_y2_output_root_mean_squared_error: 1.7147
# Epoch 69/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.9404 - y1_output_loss: 0.9239 - y2_output_loss: 2.9974 - y1_output_root_mean_squared_error: 0.9622 - y2_output_root_mean_squared_error: 1.7362 - val_loss: 7.4564 - val_y1_output_loss: 2.3040 - val_y2_output_loss: 5.0282 - val_y1_output_root_mean_squared_error: 1.5300 - val_y2_output_root_mean_squared_error: 2.2617
# Epoch 70/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.2464 - y1_output_loss: 0.7799 - y2_output_loss: 2.4700 - y1_output_root_mean_squared_error: 0.8831 - y2_output_root_mean_squared_error: 1.5705 - val_loss: 6.3754 - val_y1_output_loss: 1.0754 - val_y2_output_loss: 5.3621 - val_y1_output_root_mean_squared_error: 1.0038 - val_y2_output_root_mean_squared_error: 2.3168
# Epoch 71/500
# 614/614 [==============================] - 0s 156us/sample - loss: 5.2942 - y1_output_loss: 1.5681 - y2_output_loss: 3.6894 - y1_output_root_mean_squared_error: 1.2540 - y2_output_root_mean_squared_error: 1.9292 - val_loss: 12.4690 - val_y1_output_loss: 4.3633 - val_y2_output_loss: 8.1315 - val_y1_output_root_mean_squared_error: 2.0847 - val_y2_output_root_mean_squared_error: 2.8501
# Epoch 72/500
# 614/614 [==============================] - 0s 150us/sample - loss: 4.5845 - y1_output_loss: 1.1711 - y2_output_loss: 3.3749 - y1_output_root_mean_squared_error: 1.0867 - y2_output_root_mean_squared_error: 1.8449 - val_loss: 4.4215 - val_y1_output_loss: 0.9896 - val_y2_output_loss: 3.3809 - val_y1_output_root_mean_squared_error: 0.9751 - val_y2_output_root_mean_squared_error: 1.8630
# Epoch 73/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.0513 - y1_output_loss: 1.0306 - y2_output_loss: 3.0054 - y1_output_root_mean_squared_error: 1.0165 - y2_output_root_mean_squared_error: 1.7373 - val_loss: 4.3467 - val_y1_output_loss: 1.4210 - val_y2_output_loss: 2.8289 - val_y1_output_root_mean_squared_error: 1.1991 - val_y2_output_root_mean_squared_error: 1.7055
# Epoch 74/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.9716 - y1_output_loss: 0.7423 - y2_output_loss: 2.2369 - y1_output_root_mean_squared_error: 0.8643 - y2_output_root_mean_squared_error: 1.4915 - val_loss: 7.4466 - val_y1_output_loss: 1.9757 - val_y2_output_loss: 5.2800 - val_y1_output_root_mean_squared_error: 1.4283 - val_y2_output_root_mean_squared_error: 2.3252
# Epoch 75/500
# 614/614 [==============================] - 0s 150us/sample - loss: 3.0691 - y1_output_loss: 0.7560 - y2_output_loss: 2.3297 - y1_output_root_mean_squared_error: 0.8709 - y2_output_root_mean_squared_error: 1.5201 - val_loss: 6.2529 - val_y1_output_loss: 1.2518 - val_y2_output_loss: 4.9290 - val_y1_output_root_mean_squared_error: 1.1239 - val_y2_output_root_mean_squared_error: 2.2338
# Epoch 76/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.6081 - y1_output_loss: 0.9028 - y2_output_loss: 2.6850 - y1_output_root_mean_squared_error: 0.9515 - y2_output_root_mean_squared_error: 1.6440 - val_loss: 4.3987 - val_y1_output_loss: 1.3382 - val_y2_output_loss: 3.0394 - val_y1_output_root_mean_squared_error: 1.1444 - val_y2_output_root_mean_squared_error: 1.7576
# Epoch 77/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.3004 - y1_output_loss: 0.7944 - y2_output_loss: 2.4932 - y1_output_root_mean_squared_error: 0.8934 - y2_output_root_mean_squared_error: 1.5819 - val_loss: 3.2995 - val_y1_output_loss: 0.8172 - val_y2_output_loss: 2.3857 - val_y1_output_root_mean_squared_error: 0.9103 - val_y2_output_root_mean_squared_error: 1.5719
# Epoch 78/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.7129 - y1_output_loss: 0.7767 - y2_output_loss: 1.9465 - y1_output_root_mean_squared_error: 0.8780 - y2_output_root_mean_squared_error: 1.3936 - val_loss: 4.1815 - val_y1_output_loss: 1.2305 - val_y2_output_loss: 2.8319 - val_y1_output_root_mean_squared_error: 1.1183 - val_y2_output_root_mean_squared_error: 1.7120
# Epoch 79/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.7562 - y1_output_loss: 0.6457 - y2_output_loss: 2.0960 - y1_output_root_mean_squared_error: 0.8056 - y2_output_root_mean_squared_error: 1.4516 - val_loss: 3.7412 - val_y1_output_loss: 0.9413 - val_y2_output_loss: 2.7401 - val_y1_output_root_mean_squared_error: 0.9573 - val_y2_output_root_mean_squared_error: 1.6807
# Epoch 80/500
# 614/614 [==============================] - 0s 183us/sample - loss: 2.3972 - y1_output_loss: 0.6035 - y2_output_loss: 1.8082 - y1_output_root_mean_squared_error: 0.7727 - y2_output_root_mean_squared_error: 1.3417 - val_loss: 3.9311 - val_y1_output_loss: 1.4248 - val_y2_output_loss: 2.3826 - val_y1_output_root_mean_squared_error: 1.2126 - val_y2_output_root_mean_squared_error: 1.5686
# Epoch 81/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.6631 - y1_output_loss: 0.7644 - y2_output_loss: 1.9280 - y1_output_root_mean_squared_error: 0.8777 - y2_output_root_mean_squared_error: 1.3757 - val_loss: 10.3188 - val_y1_output_loss: 1.7562 - val_y2_output_loss: 8.3970 - val_y1_output_root_mean_squared_error: 1.3495 - val_y2_output_root_mean_squared_error: 2.9151
# Epoch 82/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.2048 - y1_output_loss: 0.8095 - y2_output_loss: 2.3681 - y1_output_root_mean_squared_error: 0.9034 - y2_output_root_mean_squared_error: 1.5455 - val_loss: 5.4288 - val_y1_output_loss: 1.7600 - val_y2_output_loss: 3.4844 - val_y1_output_root_mean_squared_error: 1.3501 - val_y2_output_root_mean_squared_error: 1.8990
# Epoch 83/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.0543 - y1_output_loss: 0.8860 - y2_output_loss: 2.1677 - y1_output_root_mean_squared_error: 0.9431 - y2_output_root_mean_squared_error: 1.4714 - val_loss: 3.4572 - val_y1_output_loss: 0.7570 - val_y2_output_loss: 2.5969 - val_y1_output_root_mean_squared_error: 0.8783 - val_y2_output_root_mean_squared_error: 1.6388
# Epoch 84/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.1925 - y1_output_loss: 0.9420 - y2_output_loss: 2.3155 - y1_output_root_mean_squared_error: 0.9576 - y2_output_root_mean_squared_error: 1.5085 - val_loss: 8.4348 - val_y1_output_loss: 2.8018 - val_y2_output_loss: 5.4136 - val_y1_output_root_mean_squared_error: 1.7005 - val_y2_output_root_mean_squared_error: 2.3544
# Epoch 85/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.7486 - y1_output_loss: 0.9871 - y2_output_loss: 2.7398 - y1_output_root_mean_squared_error: 0.9940 - y2_output_root_mean_squared_error: 1.6615 - val_loss: 3.9794 - val_y1_output_loss: 0.8445 - val_y2_output_loss: 3.0547 - val_y1_output_root_mean_squared_error: 0.9153 - val_y2_output_root_mean_squared_error: 1.7725
# Epoch 86/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.0441 - y1_output_loss: 0.7663 - y2_output_loss: 2.2554 - y1_output_root_mean_squared_error: 0.8772 - y2_output_root_mean_squared_error: 1.5082 - val_loss: 6.3230 - val_y1_output_loss: 2.1199 - val_y2_output_loss: 4.0545 - val_y1_output_root_mean_squared_error: 1.4740 - val_y2_output_root_mean_squared_error: 2.0372
# Epoch 87/500
# 614/614 [==============================] - 0s 176us/sample - loss: 3.3062 - y1_output_loss: 0.8948 - y2_output_loss: 2.4160 - y1_output_root_mean_squared_error: 0.9408 - y2_output_root_mean_squared_error: 1.5560 - val_loss: 3.7933 - val_y1_output_loss: 1.0417 - val_y2_output_loss: 2.6742 - val_y1_output_root_mean_squared_error: 1.0124 - val_y2_output_root_mean_squared_error: 1.6638
# Epoch 88/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.9364 - y1_output_loss: 0.8162 - y2_output_loss: 2.1005 - y1_output_root_mean_squared_error: 0.9074 - y2_output_root_mean_squared_error: 1.4536 - val_loss: 3.7960 - val_y1_output_loss: 0.8973 - val_y2_output_loss: 2.8335 - val_y1_output_root_mean_squared_error: 0.9463 - val_y2_output_root_mean_squared_error: 1.7031
# Epoch 89/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.6072 - y1_output_loss: 0.6750 - y2_output_loss: 1.9116 - y1_output_root_mean_squared_error: 0.8252 - y2_output_root_mean_squared_error: 1.3879 - val_loss: 3.1170 - val_y1_output_loss: 0.7678 - val_y2_output_loss: 2.3468 - val_y1_output_root_mean_squared_error: 0.8470 - val_y2_output_root_mean_squared_error: 1.5491
# Epoch 90/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.5280 - y1_output_loss: 0.5659 - y2_output_loss: 2.0005 - y1_output_root_mean_squared_error: 0.7542 - y2_output_root_mean_squared_error: 1.3997 - val_loss: 11.6747 - val_y1_output_loss: 1.1292 - val_y2_output_loss: 10.5540 - val_y1_output_root_mean_squared_error: 1.0682 - val_y2_output_root_mean_squared_error: 3.2456
# Epoch 91/500
# 614/614 [==============================] - 0s 157us/sample - loss: 2.6915 - y1_output_loss: 0.6147 - y2_output_loss: 2.0530 - y1_output_root_mean_squared_error: 0.7876 - y2_output_root_mean_squared_error: 1.4391 - val_loss: 3.8116 - val_y1_output_loss: 0.7664 - val_y2_output_loss: 2.9851 - val_y1_output_root_mean_squared_error: 0.8761 - val_y2_output_root_mean_squared_error: 1.7447
# Epoch 92/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.1928 - y1_output_loss: 0.8808 - y2_output_loss: 2.2953 - y1_output_root_mean_squared_error: 0.9370 - y2_output_root_mean_squared_error: 1.5214 - val_loss: 2.9141 - val_y1_output_loss: 0.6255 - val_y2_output_loss: 2.2224 - val_y1_output_root_mean_squared_error: 0.7962 - val_y2_output_root_mean_squared_error: 1.5100
# Epoch 93/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.3735 - y1_output_loss: 0.5803 - y2_output_loss: 1.7803 - y1_output_root_mean_squared_error: 0.7639 - y2_output_root_mean_squared_error: 1.3379 - val_loss: 3.4511 - val_y1_output_loss: 0.8687 - val_y2_output_loss: 2.5221 - val_y1_output_root_mean_squared_error: 0.9307 - val_y2_output_root_mean_squared_error: 1.6078
# Epoch 94/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.6635 - y1_output_loss: 0.8930 - y2_output_loss: 2.8611 - y1_output_root_mean_squared_error: 0.9472 - y2_output_root_mean_squared_error: 1.6633 - val_loss: 10.1669 - val_y1_output_loss: 1.8579 - val_y2_output_loss: 8.5300 - val_y1_output_root_mean_squared_error: 1.3229 - val_y2_output_root_mean_squared_error: 2.9012
# Epoch 95/500
# 614/614 [==============================] - 0s 158us/sample - loss: 3.1559 - y1_output_loss: 0.7854 - y2_output_loss: 2.4141 - y1_output_root_mean_squared_error: 0.8897 - y2_output_root_mean_squared_error: 1.5376 - val_loss: 11.9430 - val_y1_output_loss: 1.2696 - val_y2_output_loss: 10.5166 - val_y1_output_root_mean_squared_error: 1.1363 - val_y2_output_root_mean_squared_error: 3.2637
# Epoch 96/500
# 614/614 [==============================] - 0s 172us/sample - loss: 2.8719 - y1_output_loss: 0.7986 - y2_output_loss: 2.0648 - y1_output_root_mean_squared_error: 0.8916 - y2_output_root_mean_squared_error: 1.4411 - val_loss: 3.3324 - val_y1_output_loss: 0.7701 - val_y2_output_loss: 2.5787 - val_y1_output_root_mean_squared_error: 0.8569 - val_y2_output_root_mean_squared_error: 1.6119
# Epoch 97/500
# 614/614 [==============================] - 0s 151us/sample - loss: 2.5084 - y1_output_loss: 0.6148 - y2_output_loss: 1.9567 - y1_output_root_mean_squared_error: 0.7690 - y2_output_root_mean_squared_error: 1.3846 - val_loss: 10.9363 - val_y1_output_loss: 2.4668 - val_y2_output_loss: 8.9360 - val_y1_output_root_mean_squared_error: 1.5103 - val_y2_output_root_mean_squared_error: 2.9420
# Epoch 98/500
# 614/614 [==============================] - 0s 158us/sample - loss: 3.6725 - y1_output_loss: 0.9353 - y2_output_loss: 2.7841 - y1_output_root_mean_squared_error: 0.9680 - y2_output_root_mean_squared_error: 1.6539 - val_loss: 14.8339 - val_y1_output_loss: 3.0729 - val_y2_output_loss: 11.4137 - val_y1_output_root_mean_squared_error: 1.7821 - val_y2_output_root_mean_squared_error: 3.4144
# Epoch 99/500
# 614/614 [==============================] - 0s 153us/sample - loss: 4.0042 - y1_output_loss: 0.9460 - y2_output_loss: 3.0293 - y1_output_root_mean_squared_error: 0.9742 - y2_output_root_mean_squared_error: 1.7479 - val_loss: 3.3329 - val_y1_output_loss: 0.7774 - val_y2_output_loss: 2.5755 - val_y1_output_root_mean_squared_error: 0.8650 - val_y2_output_root_mean_squared_error: 1.6077
# Epoch 100/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.7890 - y1_output_loss: 0.7563 - y2_output_loss: 2.0520 - y1_output_root_mean_squared_error: 0.8719 - y2_output_root_mean_squared_error: 1.4243 - val_loss: 7.0410 - val_y1_output_loss: 1.1649 - val_y2_output_loss: 5.8210 - val_y1_output_root_mean_squared_error: 1.0877 - val_y2_output_root_mean_squared_error: 2.4203
# Epoch 101/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.1216 - y1_output_loss: 0.7703 - y2_output_loss: 2.3251 - y1_output_root_mean_squared_error: 0.8803 - y2_output_root_mean_squared_error: 1.5319 - val_loss: 3.8405 - val_y1_output_loss: 0.8577 - val_y2_output_loss: 2.9465 - val_y1_output_root_mean_squared_error: 0.9279 - val_y2_output_root_mean_squared_error: 1.7261
# Epoch 102/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.9115 - y1_output_loss: 0.7306 - y2_output_loss: 2.1569 - y1_output_root_mean_squared_error: 0.8573 - y2_output_root_mean_squared_error: 1.4753 - val_loss: 3.0870 - val_y1_output_loss: 0.6603 - val_y2_output_loss: 2.3682 - val_y1_output_root_mean_squared_error: 0.8142 - val_y2_output_root_mean_squared_error: 1.5570
# Epoch 103/500
# 614/614 [==============================] - 0s 154us/sample - loss: 1.9649 - y1_output_loss: 0.4841 - y2_output_loss: 1.4721 - y1_output_root_mean_squared_error: 0.6958 - y2_output_root_mean_squared_error: 1.2169 - val_loss: 3.4991 - val_y1_output_loss: 0.8063 - val_y2_output_loss: 2.5957 - val_y1_output_root_mean_squared_error: 0.9076 - val_y2_output_root_mean_squared_error: 1.6356
# Epoch 104/500
# 614/614 [==============================] - 0s 163us/sample - loss: 1.9685 - y1_output_loss: 0.4887 - y2_output_loss: 1.4768 - y1_output_root_mean_squared_error: 0.6980 - y2_output_root_mean_squared_error: 1.2170 - val_loss: 3.2796 - val_y1_output_loss: 0.8523 - val_y2_output_loss: 2.3290 - val_y1_output_root_mean_squared_error: 0.9323 - val_y2_output_root_mean_squared_error: 1.5526
# Epoch 105/500
# 614/614 [==============================] - 0s 152us/sample - loss: 2.5483 - y1_output_loss: 0.6189 - y2_output_loss: 1.9134 - y1_output_root_mean_squared_error: 0.7872 - y2_output_root_mean_squared_error: 1.3887 - val_loss: 3.8362 - val_y1_output_loss: 1.1139 - val_y2_output_loss: 2.7599 - val_y1_output_root_mean_squared_error: 1.0329 - val_y2_output_root_mean_squared_error: 1.6641
# Epoch 106/500
# 614/614 [==============================] - 0s 151us/sample - loss: 2.6537 - y1_output_loss: 0.5943 - y2_output_loss: 2.0351 - y1_output_root_mean_squared_error: 0.7745 - y2_output_root_mean_squared_error: 1.4331 - val_loss: 2.8515 - val_y1_output_loss: 0.6522 - val_y2_output_loss: 2.1146 - val_y1_output_root_mean_squared_error: 0.8158 - val_y2_output_root_mean_squared_error: 1.4785
# Epoch 107/500
# 614/614 [==============================] - 0s 174us/sample - loss: 3.0962 - y1_output_loss: 0.8934 - y2_output_loss: 2.1890 - y1_output_root_mean_squared_error: 0.9457 - y2_output_root_mean_squared_error: 1.4838 - val_loss: 2.9749 - val_y1_output_loss: 0.5854 - val_y2_output_loss: 2.3712 - val_y1_output_root_mean_squared_error: 0.7579 - val_y2_output_root_mean_squared_error: 1.5493
# Epoch 108/500
# 614/614 [==============================] - 0s 156us/sample - loss: 1.6794 - y1_output_loss: 0.4644 - y2_output_loss: 1.2205 - y1_output_root_mean_squared_error: 0.6806 - y2_output_root_mean_squared_error: 1.1028 - val_loss: 4.0500 - val_y1_output_loss: 0.8804 - val_y2_output_loss: 3.2481 - val_y1_output_root_mean_squared_error: 0.9118 - val_y2_output_root_mean_squared_error: 1.7940
# Epoch 109/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.4199 - y1_output_loss: 0.4844 - y2_output_loss: 1.9277 - y1_output_root_mean_squared_error: 0.6981 - y2_output_root_mean_squared_error: 1.3902 - val_loss: 3.5310 - val_y1_output_loss: 0.9484 - val_y2_output_loss: 2.5494 - val_y1_output_root_mean_squared_error: 0.9688 - val_y2_output_root_mean_squared_error: 1.6101
# Epoch 110/500
# 614/614 [==============================] - 0s 166us/sample - loss: 2.0520 - y1_output_loss: 0.4481 - y2_output_loss: 1.6020 - y1_output_root_mean_squared_error: 0.6723 - y2_output_root_mean_squared_error: 1.2649 - val_loss: 3.8204 - val_y1_output_loss: 0.7979 - val_y2_output_loss: 3.0850 - val_y1_output_root_mean_squared_error: 0.8756 - val_y2_output_root_mean_squared_error: 1.7475
# Epoch 111/500
# 614/614 [==============================] - 0s 151us/sample - loss: 1.7382 - y1_output_loss: 0.4280 - y2_output_loss: 1.3096 - y1_output_root_mean_squared_error: 0.6564 - y2_output_root_mean_squared_error: 1.1434 - val_loss: 3.2420 - val_y1_output_loss: 0.5712 - val_y2_output_loss: 2.6868 - val_y1_output_root_mean_squared_error: 0.7525 - val_y2_output_root_mean_squared_error: 1.6358
# Epoch 112/500
# 614/614 [==============================] - 0s 151us/sample - loss: 2.0359 - y1_output_loss: 0.4972 - y2_output_loss: 1.5270 - y1_output_root_mean_squared_error: 0.7069 - y2_output_root_mean_squared_error: 1.2394 - val_loss: 2.7595 - val_y1_output_loss: 0.5368 - val_y2_output_loss: 2.1682 - val_y1_output_root_mean_squared_error: 0.7282 - val_y2_output_root_mean_squared_error: 1.4930
# Epoch 113/500
# 614/614 [==============================] - 0s 147us/sample - loss: 1.5926 - y1_output_loss: 0.3953 - y2_output_loss: 1.1848 - y1_output_root_mean_squared_error: 0.6307 - y2_output_root_mean_squared_error: 1.0931 - val_loss: 3.0473 - val_y1_output_loss: 0.5372 - val_y2_output_loss: 2.5348 - val_y1_output_root_mean_squared_error: 0.7233 - val_y2_output_root_mean_squared_error: 1.5887
# Epoch 114/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.7456 - y1_output_loss: 0.7431 - y2_output_loss: 1.9905 - y1_output_root_mean_squared_error: 0.8618 - y2_output_root_mean_squared_error: 1.4153 - val_loss: 3.3318 - val_y1_output_loss: 0.9563 - val_y2_output_loss: 2.3187 - val_y1_output_root_mean_squared_error: 0.9844 - val_y2_output_root_mean_squared_error: 1.5371
# Epoch 115/500
# 614/614 [==============================] - 0s 147us/sample - loss: 1.9501 - y1_output_loss: 0.4623 - y2_output_loss: 1.5029 - y1_output_root_mean_squared_error: 0.6787 - y2_output_root_mean_squared_error: 1.2204 - val_loss: 3.4367 - val_y1_output_loss: 0.6861 - val_y2_output_loss: 2.7676 - val_y1_output_root_mean_squared_error: 0.8191 - val_y2_output_root_mean_squared_error: 1.6631
# Epoch 116/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.7138 - y1_output_loss: 0.6553 - y2_output_loss: 2.0378 - y1_output_root_mean_squared_error: 0.8111 - y2_output_root_mean_squared_error: 1.4339 - val_loss: 2.7516 - val_y1_output_loss: 0.5647 - val_y2_output_loss: 2.1576 - val_y1_output_root_mean_squared_error: 0.7455 - val_y2_output_root_mean_squared_error: 1.4819
# Epoch 117/500
# 614/614 [==============================] - 0s 144us/sample - loss: 1.8904 - y1_output_loss: 0.5052 - y2_output_loss: 1.3977 - y1_output_root_mean_squared_error: 0.7101 - y2_output_root_mean_squared_error: 1.1774 - val_loss: 3.4993 - val_y1_output_loss: 0.5795 - val_y2_output_loss: 2.8462 - val_y1_output_root_mean_squared_error: 0.7657 - val_y2_output_root_mean_squared_error: 1.7067
# Epoch 118/500
# 614/614 [==============================] - 0s 171us/sample - loss: 2.3641 - y1_output_loss: 0.6111 - y2_output_loss: 1.7429 - y1_output_root_mean_squared_error: 0.7804 - y2_output_root_mean_squared_error: 1.3248 - val_loss: 4.5422 - val_y1_output_loss: 1.0908 - val_y2_output_loss: 3.3419 - val_y1_output_root_mean_squared_error: 1.0564 - val_y2_output_root_mean_squared_error: 1.8510
# Epoch 119/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.1323 - y1_output_loss: 1.1575 - y2_output_loss: 2.9424 - y1_output_root_mean_squared_error: 1.0795 - y2_output_root_mean_squared_error: 1.7225 - val_loss: 2.6690 - val_y1_output_loss: 0.4845 - val_y2_output_loss: 2.1139 - val_y1_output_root_mean_squared_error: 0.7023 - val_y2_output_root_mean_squared_error: 1.4751
# Epoch 120/500
# 614/614 [==============================] - 0s 148us/sample - loss: 1.9051 - y1_output_loss: 0.4984 - y2_output_loss: 1.4080 - y1_output_root_mean_squared_error: 0.7010 - y2_output_root_mean_squared_error: 1.1890 - val_loss: 3.3726 - val_y1_output_loss: 0.9902 - val_y2_output_loss: 2.2923 - val_y1_output_root_mean_squared_error: 1.0065 - val_y2_output_root_mean_squared_error: 1.5361
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4326 - y1_output_loss: 0.1250 - y2_output_loss: 0.3040 - y1_output_root_mean_squared_error: 0.3549 - y2_output_root_mean_squared_error: 0.5538 - val_loss: 1.1200 - val_y1_output_loss: 0.2131 - val_y2_output_loss: 0.8943 - val_y1_output_root_mean_squared_error: 0.4640 - val_y2_output_root_mean_squared_error: 0.9512
# Epoch 462/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4989 - y1_output_loss: 0.1130 - y2_output_loss: 0.3866 - y1_output_root_mean_squared_error: 0.3362 - y2_output_root_mean_squared_error: 0.6212 - val_loss: 1.3479 - val_y1_output_loss: 0.2407 - val_y2_output_loss: 1.1209 - val_y1_output_root_mean_squared_error: 0.4919 - val_y2_output_root_mean_squared_error: 1.0516
# Epoch 463/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3669 - y1_output_loss: 0.1018 - y2_output_loss: 0.2638 - y1_output_root_mean_squared_error: 0.3185 - y2_output_root_mean_squared_error: 0.5152 - val_loss: 1.2447 - val_y1_output_loss: 0.2794 - val_y2_output_loss: 0.9730 - val_y1_output_root_mean_squared_error: 0.5268 - val_y2_output_root_mean_squared_error: 0.9835
# Epoch 464/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4290 - y1_output_loss: 0.1029 - y2_output_loss: 0.3285 - y1_output_root_mean_squared_error: 0.3215 - y2_output_root_mean_squared_error: 0.5706 - val_loss: 1.5595 - val_y1_output_loss: 0.3014 - val_y2_output_loss: 1.2645 - val_y1_output_root_mean_squared_error: 0.5529 - val_y2_output_root_mean_squared_error: 1.1198
# Epoch 465/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.4240 - y1_output_loss: 0.1334 - y2_output_loss: 0.2884 - y1_output_root_mean_squared_error: 0.3664 - y2_output_root_mean_squared_error: 0.5383 - val_loss: 1.1185 - val_y1_output_loss: 0.2352 - val_y2_output_loss: 0.8612 - val_y1_output_root_mean_squared_error: 0.4886 - val_y2_output_root_mean_squared_error: 0.9380
# Epoch 466/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4153 - y1_output_loss: 0.1095 - y2_output_loss: 0.3035 - y1_output_root_mean_squared_error: 0.3301 - y2_output_root_mean_squared_error: 0.5534 - val_loss: 1.2618 - val_y1_output_loss: 0.3140 - val_y2_output_loss: 0.9397 - val_y1_output_root_mean_squared_error: 0.5636 - val_y2_output_root_mean_squared_error: 0.9717
# Epoch 467/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4200 - y1_output_loss: 0.1132 - y2_output_loss: 0.3037 - y1_output_root_mean_squared_error: 0.3378 - y2_output_root_mean_squared_error: 0.5531 - val_loss: 1.3869 - val_y1_output_loss: 0.3006 - val_y2_output_loss: 1.0559 - val_y1_output_root_mean_squared_error: 0.5519 - val_y2_output_root_mean_squared_error: 1.0404
# Epoch 468/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3773 - y1_output_loss: 0.1231 - y2_output_loss: 0.2516 - y1_output_root_mean_squared_error: 0.3516 - y2_output_root_mean_squared_error: 0.5036 - val_loss: 1.2018 - val_y1_output_loss: 0.2266 - val_y2_output_loss: 0.9817 - val_y1_output_root_mean_squared_error: 0.4761 - val_y2_output_root_mean_squared_error: 0.9875
# Epoch 469/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3586 - y1_output_loss: 0.1116 - y2_output_loss: 0.2525 - y1_output_root_mean_squared_error: 0.3346 - y2_output_root_mean_squared_error: 0.4966 - val_loss: 1.7952 - val_y1_output_loss: 0.3070 - val_y2_output_loss: 1.5057 - val_y1_output_root_mean_squared_error: 0.5438 - val_y2_output_root_mean_squared_error: 1.2246
# Epoch 470/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.6803 - y1_output_loss: 0.1667 - y2_output_loss: 0.5076 - y1_output_root_mean_squared_error: 0.4101 - y2_output_root_mean_squared_error: 0.7156 - val_loss: 1.1245 - val_y1_output_loss: 0.2518 - val_y2_output_loss: 0.8635 - val_y1_output_root_mean_squared_error: 0.5015 - val_y2_output_root_mean_squared_error: 0.9344
# Epoch 471/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3477 - y1_output_loss: 0.0999 - y2_output_loss: 0.2464 - y1_output_root_mean_squared_error: 0.3173 - y2_output_root_mean_squared_error: 0.4970 - val_loss: 1.1790 - val_y1_output_loss: 0.2226 - val_y2_output_loss: 0.9636 - val_y1_output_root_mean_squared_error: 0.4703 - val_y2_output_root_mean_squared_error: 0.9787
# Epoch 472/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3590 - y1_output_loss: 0.1136 - y2_output_loss: 0.2450 - y1_output_root_mean_squared_error: 0.3348 - y2_output_root_mean_squared_error: 0.4969 - val_loss: 1.2520 - val_y1_output_loss: 0.2732 - val_y2_output_loss: 0.9904 - val_y1_output_root_mean_squared_error: 0.5219 - val_y2_output_root_mean_squared_error: 0.9898
# Epoch 473/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.5537 - y1_output_loss: 0.1291 - y2_output_loss: 0.4385 - y1_output_root_mean_squared_error: 0.3595 - y2_output_root_mean_squared_error: 0.6515 - val_loss: 3.3684 - val_y1_output_loss: 0.3696 - val_y2_output_loss: 3.1050 - val_y1_output_root_mean_squared_error: 0.6008 - val_y2_output_root_mean_squared_error: 1.7342
# Epoch 474/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.5289 - y1_output_loss: 0.1235 - y2_output_loss: 0.4046 - y1_output_root_mean_squared_error: 0.3476 - y2_output_root_mean_squared_error: 0.6388 - val_loss: 1.3802 - val_y1_output_loss: 0.3429 - val_y2_output_loss: 1.0252 - val_y1_output_root_mean_squared_error: 0.5888 - val_y2_output_root_mean_squared_error: 1.0166
# Epoch 475/500
# 614/614 [==============================] - 0s 192us/sample - loss: 0.4488 - y1_output_loss: 0.1413 - y2_output_loss: 0.3052 - y1_output_root_mean_squared_error: 0.3765 - y2_output_root_mean_squared_error: 0.5542 - val_loss: 1.4240 - val_y1_output_loss: 0.2476 - val_y2_output_loss: 1.1793 - val_y1_output_root_mean_squared_error: 0.5006 - val_y2_output_root_mean_squared_error: 1.0832
# Epoch 476/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4310 - y1_output_loss: 0.1173 - y2_output_loss: 0.3170 - y1_output_root_mean_squared_error: 0.3411 - y2_output_root_mean_squared_error: 0.5609 - val_loss: 1.3361 - val_y1_output_loss: 0.2305 - val_y2_output_loss: 1.1036 - val_y1_output_root_mean_squared_error: 0.4826 - val_y2_output_root_mean_squared_error: 1.0503
# Epoch 477/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.4357 - y1_output_loss: 0.1083 - y2_output_loss: 0.3280 - y1_output_root_mean_squared_error: 0.3294 - y2_output_root_mean_squared_error: 0.5721 - val_loss: 1.2584 - val_y1_output_loss: 0.2412 - val_y2_output_loss: 1.0129 - val_y1_output_root_mean_squared_error: 0.4921 - val_y2_output_root_mean_squared_error: 1.0081
# Epoch 478/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3025 - y1_output_loss: 0.1077 - y2_output_loss: 0.1957 - y1_output_root_mean_squared_error: 0.3288 - y2_output_root_mean_squared_error: 0.4409 - val_loss: 1.4078 - val_y1_output_loss: 0.2256 - val_y2_output_loss: 1.2077 - val_y1_output_root_mean_squared_error: 0.4717 - val_y2_output_root_mean_squared_error: 1.0887
# Epoch 479/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3209 - y1_output_loss: 0.0956 - y2_output_loss: 0.2282 - y1_output_root_mean_squared_error: 0.3067 - y2_output_root_mean_squared_error: 0.4762 - val_loss: 1.3267 - val_y1_output_loss: 0.3314 - val_y2_output_loss: 0.9763 - val_y1_output_root_mean_squared_error: 0.5818 - val_y2_output_root_mean_squared_error: 0.9941
# Epoch 480/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4113 - y1_output_loss: 0.1260 - y2_output_loss: 0.2828 - y1_output_root_mean_squared_error: 0.3560 - y2_output_root_mean_squared_error: 0.5335 - val_loss: 1.2325 - val_y1_output_loss: 0.3080 - val_y2_output_loss: 0.9077 - val_y1_output_root_mean_squared_error: 0.5620 - val_y2_output_root_mean_squared_error: 0.9574
# Epoch 481/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.5258 - y1_output_loss: 0.1292 - y2_output_loss: 0.3927 - y1_output_root_mean_squared_error: 0.3601 - y2_output_root_mean_squared_error: 0.6293 - val_loss: 1.2104 - val_y1_output_loss: 0.2461 - val_y2_output_loss: 0.9661 - val_y1_output_root_mean_squared_error: 0.4961 - val_y2_output_root_mean_squared_error: 0.9820
# Epoch 482/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.2991 - y1_output_loss: 0.1021 - y2_output_loss: 0.2036 - y1_output_root_mean_squared_error: 0.3178 - y2_output_root_mean_squared_error: 0.4451 - val_loss: 2.3300 - val_y1_output_loss: 0.2239 - val_y2_output_loss: 2.0833 - val_y1_output_root_mean_squared_error: 0.4772 - val_y2_output_root_mean_squared_error: 1.4499
# Epoch 483/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.3475 - y1_output_loss: 0.1060 - y2_output_loss: 0.2404 - y1_output_root_mean_squared_error: 0.3261 - y2_output_root_mean_squared_error: 0.4911 - val_loss: 1.1524 - val_y1_output_loss: 0.2479 - val_y2_output_loss: 0.8851 - val_y1_output_root_mean_squared_error: 0.4998 - val_y2_output_root_mean_squared_error: 0.9500
# Epoch 484/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.3373 - y1_output_loss: 0.0955 - y2_output_loss: 0.2392 - y1_output_root_mean_squared_error: 0.3099 - y2_output_root_mean_squared_error: 0.4911 - val_loss: 1.0900 - val_y1_output_loss: 0.2248 - val_y2_output_loss: 0.8507 - val_y1_output_root_mean_squared_error: 0.4767 - val_y2_output_root_mean_squared_error: 0.9288
# Epoch 485/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3889 - y1_output_loss: 0.1127 - y2_output_loss: 0.2758 - y1_output_root_mean_squared_error: 0.3370 - y2_output_root_mean_squared_error: 0.5248 - val_loss: 1.6916 - val_y1_output_loss: 0.3555 - val_y2_output_loss: 1.3241 - val_y1_output_root_mean_squared_error: 0.5973 - val_y2_output_root_mean_squared_error: 1.1553
# Epoch 486/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3472 - y1_output_loss: 0.1068 - y2_output_loss: 0.2408 - y1_output_root_mean_squared_error: 0.3267 - y2_output_root_mean_squared_error: 0.4904 - val_loss: 1.8224 - val_y1_output_loss: 0.2575 - val_y2_output_loss: 1.5478 - val_y1_output_root_mean_squared_error: 0.5074 - val_y2_output_root_mean_squared_error: 1.2510
# Epoch 487/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.6117 - y1_output_loss: 0.1722 - y2_output_loss: 0.4352 - y1_output_root_mean_squared_error: 0.4162 - y2_output_root_mean_squared_error: 0.6621 - val_loss: 1.0923 - val_y1_output_loss: 0.2266 - val_y2_output_loss: 0.8578 - val_y1_output_root_mean_squared_error: 0.4809 - val_y2_output_root_mean_squared_error: 0.9279
# Epoch 488/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3497 - y1_output_loss: 0.1092 - y2_output_loss: 0.2374 - y1_output_root_mean_squared_error: 0.3318 - y2_output_root_mean_squared_error: 0.4894 - val_loss: 1.1043 - val_y1_output_loss: 0.2398 - val_y2_output_loss: 0.8611 - val_y1_output_root_mean_squared_error: 0.4926 - val_y2_output_root_mean_squared_error: 0.9282
# Epoch 489/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.5093 - y1_output_loss: 0.1435 - y2_output_loss: 0.3636 - y1_output_root_mean_squared_error: 0.3773 - y2_output_root_mean_squared_error: 0.6058 - val_loss: 1.1083 - val_y1_output_loss: 0.2788 - val_y2_output_loss: 0.8181 - val_y1_output_root_mean_squared_error: 0.5305 - val_y2_output_root_mean_squared_error: 0.9093
# Epoch 490/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3942 - y1_output_loss: 0.1167 - y2_output_loss: 0.2786 - y1_output_root_mean_squared_error: 0.3417 - y2_output_root_mean_squared_error: 0.5268 - val_loss: 1.4451 - val_y1_output_loss: 0.3565 - val_y2_output_loss: 1.0718 - val_y1_output_root_mean_squared_error: 0.5972 - val_y2_output_root_mean_squared_error: 1.0433
# Epoch 491/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.3506 - y1_output_loss: 0.1122 - y2_output_loss: 0.2366 - y1_output_root_mean_squared_error: 0.3357 - y2_output_root_mean_squared_error: 0.4877 - val_loss: 1.2634 - val_y1_output_loss: 0.3031 - val_y2_output_loss: 0.9447 - val_y1_output_root_mean_squared_error: 0.5516 - val_y2_output_root_mean_squared_error: 0.9794
# Epoch 492/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.3479 - y1_output_loss: 0.1087 - y2_output_loss: 0.2384 - y1_output_root_mean_squared_error: 0.3305 - y2_output_root_mean_squared_error: 0.4885 - val_loss: 1.1630 - val_y1_output_loss: 0.2441 - val_y2_output_loss: 0.9126 - val_y1_output_root_mean_squared_error: 0.4953 - val_y2_output_root_mean_squared_error: 0.9580
# Epoch 493/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3818 - y1_output_loss: 0.0995 - y2_output_loss: 0.2852 - y1_output_root_mean_squared_error: 0.3160 - y2_output_root_mean_squared_error: 0.5310 - val_loss: 1.4365 - val_y1_output_loss: 0.2092 - val_y2_output_loss: 1.2380 - val_y1_output_root_mean_squared_error: 0.4587 - val_y2_output_root_mean_squared_error: 1.1073
# Epoch 494/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.4033 - y1_output_loss: 0.1120 - y2_output_loss: 0.2885 - y1_output_root_mean_squared_error: 0.3360 - y2_output_root_mean_squared_error: 0.5389 - val_loss: 1.1578 - val_y1_output_loss: 0.2692 - val_y2_output_loss: 0.8631 - val_y1_output_root_mean_squared_error: 0.5243 - val_y2_output_root_mean_squared_error: 0.9396
# Epoch 495/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.4746 - y1_output_loss: 0.1529 - y2_output_loss: 0.3191 - y1_output_root_mean_squared_error: 0.3924 - y2_output_root_mean_squared_error: 0.5662 - val_loss: 1.2528 - val_y1_output_loss: 0.2073 - val_y2_output_loss: 1.0343 - val_y1_output_root_mean_squared_error: 0.4564 - val_y2_output_root_mean_squared_error: 1.0220
# Epoch 496/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.3738 - y1_output_loss: 0.0996 - y2_output_loss: 0.2723 - y1_output_root_mean_squared_error: 0.3170 - y2_output_root_mean_squared_error: 0.5228 - val_loss: 1.0927 - val_y1_output_loss: 0.2538 - val_y2_output_loss: 0.8211 - val_y1_output_root_mean_squared_error: 0.5076 - val_y2_output_root_mean_squared_error: 0.9138
# Epoch 497/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.3950 - y1_output_loss: 0.1148 - y2_output_loss: 0.2780 - y1_output_root_mean_squared_error: 0.3398 - y2_output_root_mean_squared_error: 0.5287 - val_loss: 1.1749 - val_y1_output_loss: 0.2357 - val_y2_output_loss: 0.9148 - val_y1_output_root_mean_squared_error: 0.4889 - val_y2_output_root_mean_squared_error: 0.9674
# Epoch 498/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.5804 - y1_output_loss: 0.1697 - y2_output_loss: 0.4212 - y1_output_root_mean_squared_error: 0.4030 - y2_output_root_mean_squared_error: 0.6465 - val_loss: 6.0509 - val_y1_output_loss: 2.0448 - val_y2_output_loss: 3.9046 - val_y1_output_root_mean_squared_error: 1.4511 - val_y2_output_root_mean_squared_error: 1.9863
# Epoch 499/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.7694 - y1_output_loss: 0.2621 - y2_output_loss: 0.5026 - y1_output_root_mean_squared_error: 0.5127 - y2_output_root_mean_squared_error: 0.7117 - val_loss: 1.3461 - val_y1_output_loss: 0.3631 - val_y2_output_loss: 0.9696 - val_y1_output_root_mean_squared_error: 0.6039 - val_y2_output_root_mean_squared_error: 0.9907
# Epoch 500/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3238 - y1_output_loss: 0.0946 - y2_output_loss: 0.2290 - y1_output_root_mean_squared_error: 0.3071 - y2_output_root_mean_squared_error: 0.4791 - val_loss: 1.1746 - val_y1_output_loss: 0.2464 - val_y2_output_loss: 0.9104 - val_y1_output_root_mean_squared_error: 0.4974 - val_y2_output_root_mean_squared_error: 0.9629

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss: np.ndarray
Y1_loss: np.ndarray
Y2_loss: np.ndarray
Y1_rmse: np.ndarray
Y2_rmse: np.ndarray
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(
    x=norm_test_X, y=test_Y
)
print(f"Loss = {loss}, Y1_loss = {Y1_loss}, Y1_mse = {Y1_rmse}, Y2_loss = \
{Y2_loss}, Y2_mse = {Y2_rmse}")
# Out:
# 154/154 [==============================] - 0s 34us/sample - loss: 1.1746 - y1_output_loss: 0.2442 - y2_output_loss: 0.9127 - y1_output_root_mean_squared_error: 0.4974 - y2_output_root_mean_squared_error: 0.9629
# Loss = 1.1746448177795905, Y1_loss = 0.2441960573196411, Y1_mse = 0.49736878275871277, Y2_loss = 0.9126628637313843, Y2_mse = 0.9629481434822083

# %%
# Plot the loss and mse
Y_pred: np.ndarray = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(
    metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6
)
plot_metrics(
    metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7
)
